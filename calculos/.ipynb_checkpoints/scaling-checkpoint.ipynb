# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
PS1=pd.read_csv("P_new/P_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS2=pd.read_csv("P_new/P_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS3=pd.read_csv("P_new/P_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS1=pd.read_csv("He2_new/He2_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS2=pd.read_csv("He2_new/He2_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS3=pd.read_csv("He2_new/He2_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS1=pd.read_csv("Be4_new/Be4_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS2=pd.read_csv("Be4_new/Be4_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS3=pd.read_csv("Be4_new/Be4_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS1=pd.read_csv("C6_new/C6_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS2=pd.read_csv("C6_new/C6_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS3=pd.read_csv("C6_new/C6_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS1=pd.read_csv("O8_new/O8_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS2=pd.read_csv("O8_new/O8_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS3=pd.read_csv("O8_new/O8_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
PNS1=pd.read_csv("P_new/P_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
PNS2=pd.read_csv("P_new/P_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
PNS3=pd.read_csv("P_new/P_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

# %%
HeNS1=pd.read_csv("He2_new/He2_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS2=pd.read_csv("He2_new/He2_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS3=pd.read_csv("He2_new/He2_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
BeNS1=pd.read_csv("Be4_new/Be4_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS2=pd.read_csv("Be4_new/Be4_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS3=pd.read_csv("Be4_new/Be4_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
CNS1=pd.read_csv("C6_new/C6_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
CNS2=pd.read_csv("C6_new/C6_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
CNS3=pd.read_csv("C6_new/C6_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
ONS1=pd.read_csv("O8_new/O8_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
ONS2=pd.read_csv("O8_new/O8_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
ONS3=pd.read_csv("O8_new/O8_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

# %%
head_adn=list(PS1.columns.values)
head_CHn=list(PS2.columns.values)
head_PYR=list(PS3.columns.values)

# %%
headNS_adn=list(PNS1.columns.values)
headNS_CHn=list(PNS2.columns.values)
headNS_PYR=list(PNS3.columns.values)

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

fig = plt.figure(figsize=(15,10))
ax1 = plt.subplot(121)

pline=plt.plot(PNS1['ENERGY'],PNS1['ADENINA'],'k',label='p')
Heline=plt.plot(HeNS1['ENERGY'],HeNS1['ADENINA'],'r',label=r'He$^{2+}$')
Beline=plt.plot(BeNS1['ENERGY'],BeNS1['ADENINA'],'tab:green',label=r'Be$^{4+}$')
Cline=plt.plot(CNS1['ENERGY'],CNS1['ADENINA'],'tab:blue',label=r'C$^{6+}$')
Oline=plt.plot(ONS1['ENERGY'],ONS1['ADENINA'],'tab:orange',label=r'O$^{8+}$')

for i in headNS_adn:
    plt.plot(PNS1['ENERGY'],PNS1[i],'k', label='_nolegend_')
    plt.plot(HeNS1['ENERGY'],HeNS1[i],'r', label='_nolegend_')
    plt.plot(BeNS1['ENERGY'],BeNS1[i],'tab:green', label='_nolegend_')
    plt.plot(CNS1['ENERGY'],CNS1[i],'tab:blue', label='_nolegend_')
    plt.plot(ONS1['ENERGY'],ONS1[i],'tab:orange', label='_nolegend_')
for i in headNS_CHn:
    plt.plot(PNS2['ENERGY'],PNS2[i],'k', label='_nolegend_')
    plt.plot(HeNS2['ENERGY'],HeNS2[i],'r', label='_nolegend_')
    plt.plot(BeNS2['ENERGY'],BeNS2[i],'tab:green', label='_nolegend_')
    plt.plot(CNS2['ENERGY'],CNS2[i],'tab:blue', label='_nolegend_')
    plt.plot(ONS2['ENERGY'],ONS2[i],'tab:orange', label='_nolegend_')
for i in headNS_PYR:
    plt.plot(PNS3['ENERGY'],PNS3[i],'k', label='_nolegend_')
    plt.plot(HeNS3['ENERGY'],HeNS3[i],'r', label='_nolegend_')
    plt.plot(BeNS3['ENERGY'],BeNS3[i],'tab:green', label='_nolegend_')
    plt.plot(CNS3['ENERGY'],CNS3[i],'tab:blue', label='_nolegend_')
    plt.plot(ONS3['ENERGY'],ONS3[i],'tab:orange', label='_nolegend_')
plt.xlim(100,10000)
plt.ylim(0.05,100)
plt.yscale('log')
plt.xscale('log')
plt.axvline(2000,linestyle='--',color='tab:gray')
plt.tick_params(labelsize=20);
plt.xlabel("Energy (keV)", fontsize=24)
plt.ylabel("Cross Section (a.u.)", fontsize=24)
ax1.legend(loc='lower left',fontsize=20)

ax2 = plt.subplot(122)
for i in head_adn:
    plt.plot(PS1['ENERGY'],PS1[i],'k', label='_nolegend_')
    plt.plot(HeS1['ENERGY'],HeS1[i],'r', label='_nolegend_')
    plt.plot(BeS1['ENERGY'],BeS1[i],'tab:green', label='_nolegend_')
    plt.plot(CS1['ENERGY'],CS1[i],'tab:blue', label='_nolegend_')
    plt.plot(OS1['ENERGY'],OS1[i],'tab:orange', label='_nolegend_')
for i in head_CHn:
    plt.plot(PS2['ENERGY'],PS2[i],'k', label='_nolegend_')
    plt.plot(HeS2['ENERGY'],HeS2[i],'r', label='_nolegend_')
    plt.plot(BeS2['ENERGY'],BeS2[i],'tab:green', label='_nolegend_')
    plt.plot(CS2['ENERGY'],CS2[i],'tab:blue', label='_nolegend_')
    plt.plot(OS2['ENERGY'],OS2[i],'tab:orange', label='_nolegend_')
for i in head_PYR:
    plt.plot(PS3['ENERGY'],PS3[i],'k', label='_nolegend_')
    plt.plot(HeS3['ENERGY'],HeS3[i],'r', label='_nolegend_')
    plt.plot(BeS3['ENERGY'],BeS3[i],'tab:green', label='_nolegend_')
    plt.plot(CS3['ENERGY'],CS3[i],'tab:blue', label='_nolegend_')
    plt.plot(OS3['ENERGY'],OS3[i],'tab:orange', label='_nolegend_')
plt.xlim(100,10000)
plt.ylim(0.05,100)
plt.yscale('log')
plt.xscale('log')
plt.axvline(2000,linestyle='--',color='tab:gray')
plt.tick_params(labelsize=20);
plt.xlabel("Energy (keV)", fontsize=24)
# plt.ylabel("Cross Section (a.u.)", fontsize=24)
ax1.legend(loc='lower left',fontsize=20)

plt.savefig("scaling75.eps")
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(PS1['ENERGY'],PS1['SLADENINA'],'k')
plt.plot(PS1['ENERGY'],PS1['SLBACKBONE'],'k')
plt.plot(PS1['ENERGY'],PS1['SLCITOSINA'],'k')
plt.plot(PS1['ENERGY'],PS1['SLDRYDNA'],'k')
plt.plot(PS1['ENERGY'],PS1['SLGUANINA'],'k')
plt.plot(PS1['ENERGY'],PS1['SLTIMINA'],'k')
plt.plot(PS1['ENERGY'],PS1['SLURACILO'],'k')
plt.plot(PS2['ENERGY'],PS2['SLC2H2'],'k')
plt.plot(PS2['ENERGY'],PS2['SLC2H4'],'k')
plt.plot(PS2['ENERGY'],PS2['SLC2H6'],'k')
plt.plot(PS2['ENERGY'],PS2['SLC6H6'],'k')
plt.plot(PS2['ENERGY'],PS2['SLCH4'],'k')
plt.plot(PS3['ENERGY'],PS3['SLC1H5N1'],'k')
plt.plot(PS3['ENERGY'],PS3['SLC2H7N1'],'k')
plt.plot(PS3['ENERGY'],PS3['SLC4H4N2'],'k')
plt.plot(PS3['ENERGY'],PS3['SLC4H8O1'],'k')
plt.plot(PS3['ENERGY'],PS3['SLC5H5N1'],'k')
plt.plot(HeS1['ENERGY'],HeS1['SLADENINA'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLBACKBONE'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLCITOSINA'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLDRYDNA'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLGUANINA'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLTIMINA'],'r')
plt.plot(HeS1['ENERGY'],HeS1['SLURACILO'],'r')
plt.plot(HeS2['ENERGY'],HeS2['SLC2H2'],'r')
plt.plot(HeS2['ENERGY'],HeS2['SLC2H4'],'r')
plt.plot(HeS2['ENERGY'],HeS2['SLC2H6'],'r')
plt.plot(HeS2['ENERGY'],HeS2['SLC6H6'],'r')
plt.plot(HeS2['ENERGY'],HeS2['SLCH4'],'r')
plt.plot(HeS3['ENERGY'],HeS3['SLC1H5N1'],'r')
plt.plot(HeS3['ENERGY'],HeS3['SLC2H7N1'],'r')
plt.plot(HeS3['ENERGY'],HeS3['SLC4H4N2'],'r')
plt.plot(HeS3['ENERGY'],HeS3['SLC4H8O1'],'r')
plt.plot(HeS3['ENERGY'],HeS3['SLC5H5N1'],'r')
plt.plot(BeS1['ENERGY'],BeS1['SLADENINA'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLBACKBONE'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLCITOSINA'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLDRYDNA'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLGUANINA'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLTIMINA'],'tab:green')
plt.plot(BeS1['ENERGY'],BeS1['SLURACILO'],'tab:green')
plt.plot(BeS2['ENERGY'],BeS2['SLC2H2'],'tab:green')
plt.plot(BeS2['ENERGY'],BeS2['SLC2H4'],'tab:green')
plt.plot(BeS2['ENERGY'],BeS2['SLC2H6'],'tab:green')
plt.plot(BeS2['ENERGY'],BeS2['SLC6H6'],'tab:green')
plt.plot(BeS2['ENERGY'],BeS2['SLCH4'],'tab:green')
plt.plot(BeS3['ENERGY'],BeS3['SLC1H5N1'],'tab:green')
plt.plot(BeS3['ENERGY'],BeS3['SLC2H7N1'],'tab:green')
plt.plot(BeS3['ENERGY'],BeS3['SLC4H4N2'],'tab:green')
plt.plot(BeS3['ENERGY'],BeS3['SLC4H8O1'],'tab:green')
plt.plot(BeS3['ENERGY'],BeS3['SLC5H5N1'],'tab:green')
plt.plot(CS1['ENERGY'],CS1['SLADENINA'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLBACKBONE'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLCITOSINA'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLDRYDNA'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLGUANINA'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLTIMINA'],'tab:blue')
plt.plot(CS1['ENERGY'],CS1['SLURACILO'],'tab:blue')
plt.plot(CS2['ENERGY'],CS2['SLC2H2'],'tab:blue')
plt.plot(CS2['ENERGY'],CS2['SLC2H4'],'tab:blue')
plt.plot(CS2['ENERGY'],CS2['SLC2H6'],'tab:blue')
plt.plot(CS2['ENERGY'],CS2['SLC6H6'],'tab:blue')
plt.plot(CS2['ENERGY'],CS2['SLCH4'],'tab:blue')
plt.plot(CS3['ENERGY'],CS3['SLC1H5N1'],'tab:blue')
plt.plot(CS3['ENERGY'],CS3['SLC2H7N1'],'tab:blue')
plt.plot(CS3['ENERGY'],CS3['SLC4H4N2'],'tab:blue')
plt.plot(CS3['ENERGY'],CS3['SLC4H8O1'],'tab:blue')
plt.plot(CS3['ENERGY'],CS3['SLC5H5N1'],'tab:blue')
plt.plot(OS1['ENERGY'],OS1['SLADENINA'],'tab:orange')
plt.plot(OS1['ENERGY'],OS1['SLBACKBONE'],'tab:orange')
plt.plot(OS1['ENERGY'],OS1['SLCITOSINA'],'tab:orange')
plt.plot(OS1['ENERGY'],OS1['SLDRYDNA'],'tab:orange')
plt.plot(OS1['ENERGY'],OS1['SLGUANINA'],'tab:orange')
plt.plot(OS1['ENERGY'],OS1['SLTIMINA'],'tab:orange')
plt.plot(OS2['ENERGY'],OS2['SLC2H2'],'tab:orange')
plt.plot(OS2['ENERGY'],OS2['SLC2H4'],'tab:orange')
plt.plot(OS2['ENERGY'],OS2['SLC2H6'],'tab:orange')
plt.plot(OS2['ENERGY'],OS2['SLC6H6'],'tab:orange')
plt.plot(OS2['ENERGY'],OS2['SLCH4'],'tab:orange')
plt.plot(OS3['ENERGY'],OS3['SLC1H5N1'],'tab:orange')
plt.plot(OS3['ENERGY'],OS3['SLC2H7N1'],'tab:orange')
plt.plot(OS3['ENERGY'],OS3['SLC4H4N2'],'tab:orange')
plt.plot(OS3['ENERGY'],OS3['SLC4H8O1'],'tab:orange')
plt.plot(OS3['ENERGY'],OS3['SLC5H5N1'],'tab:orange')





plt.xlim(100,10000)
plt.ylim(0.05,100)
plt.yscale('log')
plt.xscale('log')
plt.axvline(2000,linestyle='--',color='tab:gray')
plt.tick_params(labelsize=20);
plt.xlabel("Energy (keV)", fontsize=24)
plt.ylabel("Cross Section (a.u.)", fontsize=24)
plt.savefig("scaling75.eps")
plt.show()

# %%
plt.plot(PNS1['ENERGY'],PNS1['SLADENINA'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLBACKBONE'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLCITOSINA'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLDRYDNA'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLGUANINA'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLTIMINA'],'k')
plt.plot(PNS1['ENERGY'],PNS1['SLURACILO'],'k')
plt.plot(PNS2['ENERGY'],PNS2['SLC2H2'],'k')
plt.plot(PNS2['ENERGY'],PNS2['SLC2H4'],'k')
plt.plot(PNS2['ENERGY'],PNS2['SLC2H6'],'k')
plt.plot(PNS2['ENERGY'],PNS2['SLC6H6'],'k')
plt.plot(PNS2['ENERGY'],PNS2['SLCH4'],'k')
plt.plot(PNS3['ENERGY'],PNS3['SLC1H5N1'],'k')
plt.plot(PNS3['ENERGY'],PNS3['SLC2H7N1'],'k')
plt.plot(PNS3['ENERGY'],PNS3['SLC4H4N2'],'k')
plt.plot(PNS3['ENERGY'],PNS3['SLC4H8O1'],'k')
plt.plot(PNS3['ENERGY'],PNS3['SLC5H5N1'],'k')


plt.plot(HeNS1['ENERGY'],HeNS1['SLADENINA'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLBACKBONE'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLCITOSINA'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLDRYDNA'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLGUANINA'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLTIMINA'],'r')
plt.plot(HeNS1['ENERGY'],HeNS1['SLURACILO'],'r')
plt.plot(HeNS2['ENERGY'],HeNS2['SLC2H2'],'r')
plt.plot(HeNS2['ENERGY'],HeNS2['SLC2H4'],'r')
plt.plot(HeNS2['ENERGY'],HeNS2['SLC2H6'],'r')
plt.plot(HeNS2['ENERGY'],HeNS2['SLC6H6'],'r')
plt.plot(HeNS2['ENERGY'],HeNS2['SLCH4'],'r')
plt.plot(HeNS3['ENERGY'],HeNS3['SLC1H5N1'],'r')
plt.plot(HeNS3['ENERGY'],HeNS3['SLC2H7N1'],'r')
plt.plot(HeNS3['ENERGY'],HeNS3['SLC4H4N2'],'r')
plt.plot(HeNS3['ENERGY'],HeNS3['SLC4H8O1'],'r')
plt.plot(HeNS3['ENERGY'],HeNS3['SLC5H5N1'],'r')


plt.plot(BeNS1['ENERGY'],BeNS1['SLADENINA'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLBACKBONE'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLCITOSINA'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLDRYDNA'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLGUANINA'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLTIMINA'],'tab:green')
plt.plot(BeNS1['ENERGY'],BeNS1['SLURACILO'],'tab:green')
plt.plot(BeNS2['ENERGY'],BeNS2['SLC2H2'],'tab:green')
plt.plot(BeNS2['ENERGY'],BeNS2['SLC2H4'],'tab:green')
plt.plot(BeNS2['ENERGY'],BeNS2['SLC2H6'],'tab:green')
plt.plot(BeNS2['ENERGY'],BeNS2['SLC6H6'],'tab:green')
plt.plot(BeNS2['ENERGY'],BeNS2['SLCH4'],'tab:green')
plt.plot(BeNS3['ENERGY'],BeNS3['SLC1H5N1'],'tab:green')
plt.plot(BeNS3['ENERGY'],BeNS3['SLC2H7N1'],'tab:green')
plt.plot(BeNS3['ENERGY'],BeNS3['SLC4H4N2'],'tab:green')
plt.plot(BeNS3['ENERGY'],BeNS3['SLC4H8O1'],'tab:green')
plt.plot(BeNS3['ENERGY'],BeNS3['SLC5H5N1'],'tab:green')


plt.plot(CNS1['ENERGY'],CNS1['SLADENINA'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLBACKBONE'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLCITOSINA'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLDRYDNA'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLGUANINA'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLTIMINA'],'tab:blue')
plt.plot(CNS1['ENERGY'],CNS1['SLURACILO'],'tab:blue')
plt.plot(CNS2['ENERGY'],CNS2['SLC2H2'],'tab:blue')
plt.plot(CNS2['ENERGY'],CNS2['SLC2H4'],'tab:blue')
plt.plot(CNS2['ENERGY'],CNS2['SLC2H6'],'tab:blue')
plt.plot(CNS2['ENERGY'],CNS2['SLC6H6'],'tab:blue')
plt.plot(CNS2['ENERGY'],CNS2['SLCH4'],'tab:blue')
plt.plot(CNS3['ENERGY'],CNS3['SLC1H5N1'],'tab:blue')
plt.plot(CNS3['ENERGY'],CNS3['SLC2H7N1'],'tab:blue')
plt.plot(CNS3['ENERGY'],CNS3['SLC4H4N2'],'tab:blue')
plt.plot(CNS3['ENERGY'],CNS3['SLC4H8O1'],'tab:blue')
plt.plot(CNS3['ENERGY'],CNS3['SLC5H5N1'],'tab:blue')

plt.plot(ONS1['ENERGY'],ONS1['SLADENINA'],'tab:orange')
plt.plot(ONS1['ENERGY'],ONS1['SLBACKBONE'],'tab:orange')
plt.plot(ONS1['ENERGY'],ONS1['SLCITOSINA'],'tab:orange')
plt.plot(ONS1['ENERGY'],ONS1['SLDRYDNA'],'tab:orange')
plt.plot(ONS1['ENERGY'],ONS1['SLGUANINA'],'tab:orange')
plt.plot(ONS1['ENERGY'],ONS1['SLTIMINA'],'tab:orange')
plt.plot(ONS2['ENERGY'],ONS2['SLC2H2'],'tab:orange')
plt.plot(ONS2['ENERGY'],ONS2['SLC2H4'],'tab:orange')
plt.plot(ONS2['ENERGY'],ONS2['SLC2H6'],'tab:orange')
plt.plot(ONS2['ENERGY'],ONS2['SLC6H6'],'tab:orange')
plt.plot(ONS2['ENERGY'],ONS2['SLCH4'],'tab:orange')
plt.plot(ONS3['ENERGY'],ONS3['SLC1H5N1'],'tab:orange')
plt.plot(ONS3['ENERGY'],ONS3['SLC2H7N1'],'tab:orange')
plt.plot(ONS3['ENERGY'],ONS3['SLC4H4N2'],'tab:orange')
plt.plot(ONS3['ENERGY'],ONS3['SLC4H8O1'],'tab:orange')
plt.plot(ONS3['ENERGY'],ONS3['SLC5H5N1'],'tab:orange')
