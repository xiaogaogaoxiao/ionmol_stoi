# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
convMb=0.28002*100

def convkeV(x):
    return 25.0*(x**2)

# %%
convcm2=0.28002

def convMeV(x):
    return 25.0*(x**2)/1000.

# %%
folder="~/ionmol_stoi/calculos/"

# %%
s = open("/home/ale/ionmol_stoi/calculos/O8/O8_CDW.dat").read()
s = s.replace('D+', 'E+')
s = s.replace('D-', 'E-')
f = open("/home/ale/ionmol_stoi/calculos/O8/O8_CDW.dat", 'w')
f.write(s)
f.close()

# %%
irows=14

# %%
P_CDW=[]
He_CDW=[]
Be_CDW=[]
C_CDW=[]
O_CDW=[]
for i in range(5):
    dump=pd.read_csv(folder+"P/P_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    dumhe=pd.read_csv(folder+"He2/He2_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    dumbe=pd.read_csv(folder+"Be4/Be4_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    dumc=pd.read_csv(folder+"C6/C6_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    dumo=pd.read_csv(folder+"O8/O8_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    P_CDW.append(dump)
    He_CDW.append(dumhe)
    Be_CDW.append(dumbe)
    C_CDW.append(dumc)
    O_CDW.append(dumo)

# %% [markdown]
# # Some data points are scaled born calculations

# %%
ht=He_CDW[0]
ct=He_CDW[1]
nt=He_CDW[2]
ot=He_CDW[3]
pt=He_CDW[4]
for i in range(9,14):
    ht.at[i,4]=ht[4][i]*2**2
    ct.at[i,4]=ct[4][i]*2**2
    nt.at[i,4]=nt[4][i]*2**2
    ot.at[i,4]=ot[4][i]*2**2
    pt.at[i,4]=pt[4][i]*2**2

# %%
ht=Be_CDW[0]
ct=Be_CDW[1]
nt=Be_CDW[2]
ot=Be_CDW[3]
pt=Be_CDW[4]
ht.at[13,4]=ht[4][13]*4**2
ct.at[13,4]=ct[4][13]*4**2
nt.at[13,4]=nt[4][13]*4**2
ot.at[13,4]=ot[4][13]*4**2
pt.at[13,4]=pt[4][13]*4**2

# %%
ht=C_CDW[0]
ct=C_CDW[1]
nt=C_CDW[2]
ot=C_CDW[3]
pt=C_CDW[4]
ht.at[13,4]=ht[4][13]*6**2
ct.at[13,4]=ct[4][13]*6**2
nt.at[13,4]=nt[4][13]*6**2
ot.at[13,4]=ot[4][13]*6**2
pt.at[13,4]=pt[4][13]*6**2

# %%
ht=O_CDW[0]
ct=O_CDW[1]
nt=O_CDW[2]
ot=O_CDW[3]
pt=O_CDW[4]
ht.at[13,4]=ht[4][13]*8**2
ct.at[13,4]=ct[4][13]*8**2
nt.at[13,4]=nt[4][13]*8**2
ot.at[13,4]=ot[4][13]*8**2
pt.at[13,4]=pt[4][13]*8**2

# %% [markdown]
# # Copy data into target_projectile named pandas

# %%
H_P=P_CDW[0]
C_P=P_CDW[1]
N_P=P_CDW[2]
O_P=P_CDW[3]
P_P=P_CDW[4]

# %%
H_He=He_CDW[0]
C_He=He_CDW[1]
N_He=He_CDW[2]
O_He=He_CDW[3]
P_He=He_CDW[4]

# %%
H_Be=Be_CDW[0]
C_Be=Be_CDW[1]
N_Be=Be_CDW[2]
O_Be=Be_CDW[3]
P_Be=Be_CDW[4]

# %%
H_C=C_CDW[0]
C_C=C_CDW[1]
N_C=C_CDW[2]
O_C=C_CDW[3]
P_C=C_CDW[4]

# %%
H_O=O_CDW[0]
C_O=O_CDW[1]
N_O=O_CDW[2]
O_O=O_CDW[3]
P_O=O_CDW[4]

# %% [markdown]
# # Antiproton data

# %%
AP_CDW=[]
for i in range(6):
    dumap=pd.read_csv(folder+"AP/AP_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    AP_CDW.append(dumap)

# %%
H_AP=AP_CDW[0]
H_AP[4]=H_AP[4]/4.
C_AP=AP_CDW[1]
N_AP=AP_CDW[2]
O_AP=AP_CDW[3]
P_AP=AP_CDW[4]
S_AP=AP_CDW[5]

# %% [markdown]
# # Sulfur data

# %%
S_CDW=[]
for i in range(5):
    dumap=pd.read_csv(folder+"sulfur/S_CDW.dat",sep=' ',delimiter='\s+',header=None,skiprows=(1+irows)*i+1,nrows=irows)
    S_CDW.append(dumap)

# %%
S_P=S_CDW[0]
S_He=S_CDW[1]
S_Be=S_CDW[2]
S_C=S_CDW[3]
S_O=S_CDW[4]

# %% [markdown]
# # Implementing Cubic Spline

# %%
from scipy import interpolate

def interp_XS(XY,ix,iy,kind):
    x=XY[ix].values
    y=XY[iy].values
    n=len(x)
    spline = interpolate.interp1d(x, y, kind=kind)
    xnew = np.arange(x[0], x[n-1], 0.1)
    ynew = spline(xnew)
    XYnew = pd.DataFrame({ix:xnew, iy:ynew})
    return XYnew

# %%
H_Pint=interp_XS(H_P,1,4,'cubic')
C_Pint=interp_XS(C_P,1,4,'cubic')
N_Pint=interp_XS(N_P,1,4,'cubic')
O_Pint=interp_XS(O_P,1,4,'cubic')
P_Pint=interp_XS(P_P,1,4,'cubic')
S_Pint=interp_XS(S_P,1,4,'cubic')

# %%
H_APint=interp_XS(H_AP,1,4,'cubic')
C_APint=interp_XS(C_AP,1,4,'cubic')
N_APint=interp_XS(N_AP,1,4,'cubic')
O_APint=interp_XS(O_AP,1,4,'cubic')
P_APint=interp_XS(P_AP,1,4,'cubic')
S_APint=interp_XS(S_AP,1,4,'cubic')

# %%
H_Heint=interp_XS(H_He,1,4,'cubic')
C_Heint=interp_XS(C_He,1,4,'cubic')
N_Heint=interp_XS(N_He,1,4,'cubic')
O_Heint=interp_XS(O_He,1,4,'cubic')
P_Heint=interp_XS(P_He,1,4,'cubic')
S_Heint=interp_XS(S_He,1,4,'cubic')

# %%
H_Beint=interp_XS(H_Be,1,4,'cubic')
C_Beint=interp_XS(C_Be,1,4,'cubic')
N_Beint=interp_XS(N_Be,1,4,'cubic')
O_Beint=interp_XS(O_Be,1,4,'cubic')
P_Beint=interp_XS(P_Be,1,4,'cubic')
S_Beint=interp_XS(S_Be,1,4,'cubic')

# %%
H_Cint=interp_XS(H_C,1,4,'cubic')
C_Cint=interp_XS(C_C,1,4,'cubic')
N_Cint=interp_XS(N_C,1,4,'cubic')
O_Cint=interp_XS(O_C,1,4,'cubic')
P_Cint=interp_XS(P_C,1,4,'cubic')
S_Cint=interp_XS(S_C,1,4,'cubic')

# %%
H_Oint=interp_XS(H_O,1,4,'cubic')
C_Oint=interp_XS(C_O,1,4,'cubic')
N_Oint=interp_XS(N_O,1,4,'cubic')
O_Oint=interp_XS(O_O,1,4,'cubic')
P_Oint=interp_XS(P_O,1,4,'cubic')
S_Oint=interp_XS(S_O,1,4,'cubic')

# %%
co_p='tab:red'
co_ap='tab:red'
co_he='tab:green'
co_be='tab:blue'
co_c='tab:purple'
co_o='tab:orange'

# %%
#co_p='red'
#co_ap='red'
#co_he='darkorchid'
#co_be='royalblue'
#co_c='forestgreen'
#co_o='darkorange'

# %%
itickssize=28
iatomsize=30
ilabelsize=30
ilegsize=26

# %%
ymax
# Out:
# 840.06

# %%
dum=H_Pint[convMeV(H_Pint[1]) < 0.1]
ie100=len(dum)

# %%
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')

iwidth=2.5
xmin=convMeV(1.2)
xmax=convMeV(20)
ymin=0.07
ymax=13
xtext=4.00
ytext=3.8
iminus=0
icharge=convMeV(1.4)
ixtimes=1.
iytimes=1.

fig = plt.figure(figsize=(18,9))
ax1 = plt.subplot(231)
plt.text(xtext, ytext, 'H',fontsize=iatomsize)
plt.text(ixtimes,iytimes, r'$\times$4',fontsize=iatomsize-2)
plt.text(icharge, 4*H_Pint[4][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, 4*H_APint[4][ie100]*convcm2*1.05, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, 4*H_Heint[4][ie100]*convcm2*0.7/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, 4*H_Beint[4][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, 4*H_Cint[4][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, 4*H_Oint[4][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(H_Pint[1][ie100:]), 4*H_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(H_APint[1][ie100:]),4*H_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(H_Heint[1][ie100:]),4*H_Heint[4][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label=r'He$^{2+}$')
plt.plot(convMeV(H_Beint[1][ie100:]),4*H_Beint[4][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label=r'Be$^{4+}$')
plt.plot(convMeV(H_Cint[1][ie100:]), 4*H_Cint[4][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label=r'C$^{6+}$')
plt.plot(convMeV(H_Oint[1][ie100:]), 4*H_Oint[4][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label=r'O$^{8+}$')
plt.ylabel("Ionization Cross Section/Z$^2$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=10,position=(1,0))
# ax1.legend(loc='upper left',bbox_to_anchor=(0.06, 1.3, 0, 0),fontsize=ilegsize,ncol=6)
ax1.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor', length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

ax2 = plt.subplot(232)
plt.text(xtext, ytext, 'C',fontsize=iatomsize)
plt.text(icharge, C_Pint[4][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, C_APint[4][ie100]*convcm2*1.05, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, C_Heint[4][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, C_Beint[4][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, C_Cint[4][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, C_Oint[4][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(C_Pint[1][ie100:]), C_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(C_APint[1][ie100:]),C_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(C_Heint[1][ie100:]),C_Heint[4][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label=r'He$^{2+}$')
plt.plot(convMeV(C_Beint[1][ie100:]),C_Beint[4][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label=r'Be$^{4+}$')
plt.plot(convMeV(C_Cint[1][ie100:]), C_Cint[4][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label=r'C$^{6+}$')
plt.plot(convMeV(C_Oint[1][ie100:]), C_Oint[4][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label=r'O$^{8+}$')
ax2.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor', length=5,bottom=True, top=True, left=True, right=True);
ax2.legend(loc='lower center',bbox_to_anchor=(0.5, 1, 0, 0),fontsize=ilegsize,ncol=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

ax3 = plt.subplot(233)
plt.text(xtext, ytext, 'N',fontsize=iatomsize)
plt.text(icharge, N_Pint[4][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, N_APint[4][ie100]*convcm2*1.05, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, N_Heint[4][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, N_Beint[4][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, N_Cint[4][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, N_Oint[4][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(N_Pint[1][ie100:]), N_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(N_APint[1][ie100:]),N_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(N_Heint[1][ie100:]),N_Heint[4][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(N_Beint[1][ie100:]),N_Beint[4][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(N_Cint[1][ie100:]), N_Cint[4][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(N_Oint[1][ie100:]), N_Oint[4][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label='_nolegend_')
ax3.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor', length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### Oxigeno ###
ax4 = plt.subplot(234)
plt.text(xtext, ytext, 'O',fontsize=iatomsize)
plt.text(icharge, O_Pint[4][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, O_APint[4][ie100]*convcm2*1.05, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, O_Heint[4][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, O_Beint[4][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, O_Cint[4][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, O_Oint[4][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(O_Pint[1][ie100:]), O_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(O_APint[1][ie100:]),O_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(O_Heint[1][ie100:]),O_Heint[4][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(O_Beint[1][ie100:]),O_Beint[4][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(O_Cint[1][ie100:]), O_Cint[4][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(O_Oint[1][ie100:]), O_Oint[4][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label='_nolegend_')
ax4.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor', length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax4.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### Sulfuro ###
ax5 = plt.subplot(235)
plt.text(xtext, ytext, 'P',fontsize=iatomsize)
plt.text(icharge, P_Pint[4][ie100]*convcm2*1.15, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, P_APint[4][ie100]*convcm2*0.85, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, P_Heint[4][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, P_Beint[4][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, P_Cint[4][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, P_Oint[4][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(P_Pint[1][ie100:]), P_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(P_APint[1][ie100:]),P_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(P_Heint[1][ie100:]),P_Heint[4][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(P_Beint[1][ie100:]),P_Beint[4][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(P_Cint[1][ie100:]), P_Cint[4][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(P_Oint[1][ie100:]), P_Oint[4][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label='_nolegend_')
plt.xlabel("Impact energy (MeV/amu)", fontsize=ilabelsize,labelpad=10)
ax5.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax5.tick_params(direction='in',which='minor', length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax5.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))


ax6 = plt.subplot(236)
plt.text(xtext, ytext, 'S',fontsize=iatomsize)
plt.text(icharge, S_Pint[4][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, S_APint[4][ie100]*convcm2*0.9, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, S_Heint[4][ie100]*convcm2*0.8, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, S_Beint[4][ie100]*convcm2*0.85, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, S_Cint[4][ie100]*convcm2*0.8, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, S_Oint[4][ie100]*convcm2*0.8, r'$+8$',color=co_o,fontsize=22)
plt.plot(convMeV(S_Pint[1][ie100:]), S_Pint[4][ie100:]*convcm2,co_p,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(S_APint[1][ie100:]),S_APint[4][ie100:]*convcm2,co_p,linestyle='--',linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(S_Heint[1][ie100:]),S_Heint[4][ie100:]*convcm2,co_he,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(S_Beint[1][ie100:]),S_Beint[4][ie100:]*convcm2,co_be,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(S_Cint[1][ie100:]), S_Cint[4][ie100:]*convcm2,co_c,linewidth=iwidth,label='_nolegend_')
plt.plot(convMeV(S_Oint[1][ie100:]), S_Oint[4][ie100:]*convcm2,co_o,linewidth=iwidth,label='_nolegend_')
ax6.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax6.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax6.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
# fig.subplots_adjust(hspace=0.05, wspace=0.05)
fig.subplots_adjust(hspace=0., wspace=0.)

plt.savefig("../atomicscaling.eps",bbox_inches='tight',transparent=True,dpi=600)
plt.show()
