# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
convMb=0.28002*100

def convkeV(x):
    return 25.0*(x**2)

# %%
convcm2=0.28002

def convMeV(x):
    return 25.0*(x**2)/1000.

# %%
folder="~/ionmol_stoi/calculos/"

# %%
PS1=pd.read_csv(folder+"P/P_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS2=pd.read_csv(folder+"P/P_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS3=pd.read_csv(folder+"P/P_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS1=pd.read_csv(folder+"He2/He2_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS2=pd.read_csv(folder+"He2/He2_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS3=pd.read_csv(folder+"He2/He2_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS1=pd.read_csv(folder+"Be4/Be4_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS1=pd.read_csv(folder+"C6/C6_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS2=pd.read_csv(folder+"C6/C6_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS3=pd.read_csv(folder+"C6/C6_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS1=pd.read_csv(folder+"O8/O8_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS2=pd.read_csv(folder+"O8/O8_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS3=pd.read_csv(folder+"O8/O8_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
PNS1=pd.read_csv(folder+"P/P_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
PNS2=pd.read_csv(folder+"P/P_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
PNS3=pd.read_csv(folder+"P/P_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
HeNS1=pd.read_csv(folder+"He2/He2_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS2=pd.read_csv(folder+"He2/He2_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS3=pd.read_csv(folder+"He2/He2_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
BeNS1=pd.read_csv(folder+"Be4/Be4_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
CNS1=pd.read_csv(folder+"C6/C6_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
CNS2=pd.read_csv(folder+"C6/C6_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
CNS3=pd.read_csv(folder+"C6/C6_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
ONS1=pd.read_csv(folder+"O8/O8_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
ONS2=pd.read_csv(folder+"O8/O8_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
ONS3=pd.read_csv(folder+"O8/O8_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

# %%
head_adn=list(PS1.columns.values)
head_CHn=list(PS2.columns.values)
head_PYR=list(PS3.columns.values)

# %%
headNS_adn=list(PNS1.columns.values)
headNS_CHn=list(PNS2.columns.values)
headNS_PYR=list(PNS3.columns.values)

# %% [markdown]
# # Convert energy from keV to a.u.

# %%
PS1['ENERGY']=np.sqrt(PS1['ENERGY']/25.)
PS2['ENERGY']=np.sqrt(PS2['ENERGY']/25.)
PS3['ENERGY']=np.sqrt(PS3['ENERGY']/25.)
HeS1['ENERGY']=np.sqrt(HeS1['ENERGY']/25.)
HeS2['ENERGY']=np.sqrt(HeS2['ENERGY']/25.)
HeS3['ENERGY']=np.sqrt(HeS3['ENERGY']/25.)
BeS1['ENERGY']=np.sqrt(BeS1['ENERGY']/25.)
BeS2['ENERGY']=np.sqrt(BeS2['ENERGY']/25.)
BeS3['ENERGY']=np.sqrt(BeS3['ENERGY']/25.)
CS1['ENERGY']=np.sqrt(CS1['ENERGY']/25.)
CS2['ENERGY']=np.sqrt(CS2['ENERGY']/25.)
CS3['ENERGY']=np.sqrt(CS3['ENERGY']/25.)
OS1['ENERGY']=np.sqrt(OS1['ENERGY']/25.)
OS2['ENERGY']=np.sqrt(OS2['ENERGY']/25.)
OS3['ENERGY']=np.sqrt(OS3['ENERGY']/25.)

# %%
PNS1['ENERGY']=np.sqrt(PNS1['ENERGY']/25.)
PNS2['ENERGY']=np.sqrt(PNS2['ENERGY']/25.)
PNS3['ENERGY']=np.sqrt(PNS3['ENERGY']/25.)
HeNS1['ENERGY']=np.sqrt(HeNS1['ENERGY']/25.)
HeNS2['ENERGY']=np.sqrt(HeNS2['ENERGY']/25.)
HeNS3['ENERGY']=np.sqrt(HeNS3['ENERGY']/25.)
BeNS1['ENERGY']=np.sqrt(BeNS1['ENERGY']/25.)
BeNS2['ENERGY']=np.sqrt(BeNS2['ENERGY']/25.)
BeNS3['ENERGY']=np.sqrt(BeNS3['ENERGY']/25.)
CNS1['ENERGY']=np.sqrt(CNS1['ENERGY']/25.)
CNS2['ENERGY']=np.sqrt(CNS2['ENERGY']/25.)
CNS3['ENERGY']=np.sqrt(CNS3['ENERGY']/25.)
ONS1['ENERGY']=np.sqrt(ONS1['ENERGY']/25.)
ONS2['ENERGY']=np.sqrt(ONS2['ENERGY']/25.)
ONS3['ENERGY']=np.sqrt(ONS3['ENERGY']/25.)

# %% [markdown]
# # Make cubic spline interpolation on data

# %%
from scipy import interpolate

def interp_XS(XY,ix,iy,kind):
    x=XY[ix].values
    y=XY[iy].values
    n=len(x)
    spline = interpolate.interp1d(x, y, kind=kind)
    xnew = np.arange(x[0], x[n-1], 0.1)
    ynew = spline(xnew)
    XYnew = pd.DataFrame({ix:xnew, iy:ynew})
    return XYnew

# %%
PS1int=[]
PNS1int=[]
PS1int=interp_XS(PS1,'ENERGY','SLURACILO','cubic')
PNS1int=interp_XS(PNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(PS1,'ENERGY',i,'cubic')
    PS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(PNS1,'ENERGY',i,'cubic')
    PNS1int[i]=dumn1[i]

PS2int=[]
PNS2int=[]
PS2int=interp_XS(PS2,'ENERGY','SLCH4','cubic')
PNS2int=interp_XS(PNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(PS2,'ENERGY',i,'cubic')
    PS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(PNS2,'ENERGY',i,'cubic')
    PNS2int[i]=dumn2[i]

PS3int=[]
PNS3int=[]
PS3int=interp_XS(PS3,'ENERGY','SLC4H4N2','cubic')
PNS3int=interp_XS(PNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(PS3,'ENERGY',i,'cubic')
    PS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(PNS3,'ENERGY',i,'cubic')
    PNS3int[i]=dumn3[i]

# %%
HeS1int=[]
HeNS1int=[]
HeS1int=interp_XS(HeS1,'ENERGY','SLURACILO','cubic')
HeNS1int=interp_XS(HeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(HeS1,'ENERGY',i,'cubic')
    HeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(HeNS1,'ENERGY',i,'cubic')
    HeNS1int[i]=dumn1[i]

HeS2int=[]
HeNS2int=[]
HeS2int=interp_XS(HeS2,'ENERGY','SLCH4','cubic')
HeNS2int=interp_XS(HeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(HeS2,'ENERGY',i,'cubic')
    HeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(HeNS2,'ENERGY',i,'cubic')
    HeNS2int[i]=dumn2[i]

HeS3int=[]
HeNS3int=[]
HeS3int=interp_XS(HeS3,'ENERGY','SLC4H4N2','cubic')
HeNS3int=interp_XS(HeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(HeS3,'ENERGY',i,'cubic')
    HeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(HeNS3,'ENERGY',i,'cubic')
    HeNS3int[i]=dumn3[i]

# %%
BeS1int=[]
BeNS1int=[]
BeS1int=interp_XS(BeS1,'ENERGY','SLURACILO','cubic')
BeNS1int=interp_XS(BeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(BeS1,'ENERGY',i,'cubic')
    BeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(BeNS1,'ENERGY',i,'cubic')
    BeNS1int[i]=dumn1[i]

BeS2int=[]
BeNS2int=[]
BeS2int=interp_XS(BeS2,'ENERGY','SLCH4','cubic')
BeNS2int=interp_XS(BeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(BeS2,'ENERGY',i,'cubic')
    BeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(BeNS2,'ENERGY',i,'cubic')
    BeNS2int[i]=dumn2[i]

BeS3int=[]
BeNS3int=[]
BeS3int=interp_XS(BeS3,'ENERGY','SLC4H4N2','cubic')
BeNS3int=interp_XS(BeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(BeS3,'ENERGY',i,'cubic')
    BeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(BeNS3,'ENERGY',i,'cubic')
    BeNS3int[i]=dumn3[i]

# %%
CS1int=[]
CNS1int=[]
CS1int=interp_XS(CS1,'ENERGY','SLURACILO','cubic')
CNS1int=interp_XS(CNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(CS1,'ENERGY',i,'cubic')
    CS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(CNS1,'ENERGY',i,'cubic')
    CNS1int[i]=dumn1[i]

CS2int=[]
CNS2int=[]
CS2int=interp_XS(CS2,'ENERGY','SLCH4','cubic')
CNS2int=interp_XS(CNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(CS2,'ENERGY',i,'cubic')
    CS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(CNS2,'ENERGY',i,'cubic')
    CNS2int[i]=dumn2[i]

CS3int=[]
CNS3int=[]
CS3int=interp_XS(CS3,'ENERGY','SLC4H4N2','cubic')
CNS3int=interp_XS(CNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(CS3,'ENERGY',i,'cubic')
    CS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(CNS3,'ENERGY',i,'cubic')
    CNS3int[i]=dumn3[i]

# %%
OS1int=[]
ONS1int=[]
OS1int=interp_XS(OS1,'ENERGY','SLURACILO','cubic')
ONS1int=interp_XS(ONS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(OS1,'ENERGY',i,'cubic')
    OS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(ONS1,'ENERGY',i,'cubic')
    ONS1int[i]=dumn1[i]

OS2int=[]
ONS2int=[]
OS2int=interp_XS(OS2,'ENERGY','SLCH4','cubic')
ONS2int=interp_XS(ONS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(OS2,'ENERGY',i,'cubic')
    OS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(ONS2,'ENERGY',i,'cubic')
    ONS2int[i]=dumn2[i]

OS3int=[]
ONS3int=[]
OS3int=interp_XS(OS3,'ENERGY','SLC4H4N2','cubic')
ONS3int=interp_XS(ONS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(OS3,'ENERGY',i,'cubic')
    OS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(ONS3,'ENERGY',i,'cubic')
    ONS3int[i]=dumn3[i]

# %%
co_p='tab:red'
co_ap='tab:red'
co_he='tab:green'
co_be='tab:blue'
co_c='tab:purple'
co_o='tab:orange'

# %%
#co_p='red'
#co_ap='red'
#co_he='darkorchid'
#co_be='royalblue'
#co_c='forestgreen'
#co_o='darkorange'

# %% [markdown]
# # Input $\bar{p}$ data, change $\sigma$ units and interpolate

# %%
APS1=pd.read_csv(folder+"AP/AP_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
APS3=pd.read_csv(folder+"AP/AP_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
if APS1['ENERGY'][0]==25: 
    APS1['ENERGY']=np.sqrt(APS1['ENERGY']/25.)
if APS3['ENERGY'][0]==25: 
    APS3['ENERGY']=np.sqrt(APS3['ENERGY']/25.)
    
head_APS1=list(APS1.columns.values)
head_APS3=list(APS3.columns.values)

# %%
APS1int=[]
APS1int=interp_XS(APS1,'ENERGY','SLURACILO','cubic')
for i in head_APS1[2:]:
    dum1=interp_XS(APS1,'ENERGY',i,'cubic')
    APS1int[i]=dum1[i]

# %%
APS3int=[]
APS3int=interp_XS(APS3,'ENERGY','SLC4H4N2','cubic')
for i in head_APS3[2:]:
    dum1=interp_XS(APS3,'ENERGY',i,'cubic')
    APS3int[i]=dum1[i]

# %% [markdown]
# # Input of experimental data

# %%
folderexp='~/ionmol_stoi/experimentos/'

A_p=pd.read_csv(folderexp+'adenina+p_iriki2011.dat',sep=' ',delimiter='\s+',header='infer')
A_e=pd.read_csv(folderexp+'adenine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
C_e=pd.read_csv(folderexp+'cytosine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
G_e=pd.read_csv(folderexp+'guanine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
T_e=pd.read_csv(folderexp+'thymine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
U_p=pd.read_csv(folderexp+'uracilo+p_itoh2013.dat',sep=' ',delimiter='\s+',header='infer')
PYR_p=pd.read_csv(folderexp+'pirimidina+p_wolff2014',sep=' ',delimiter='\s+',header='infer')
bug17=pd.read_csv(folderexp+'e_bug2017.dat',sep=' ',delimiter='\s+',header='infer')
THF_p=pd.read_csv(folderexp+'THF+p_wang2016.dat',sep=' ',delimiter='\s+',header='infer')
THF_e09=pd.read_csv(folderexp+'THF+e_fuss2009.dat',sep=' ',delimiter='\s+',header='infer')
THF_e19=pd.read_csv(folderexp+'THF+e_wolff2019.dat',sep=' ',delimiter='\s+',header='infer')
U_c4=pd.read_csv(folderexp+'uracil+c4_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_c6=pd.read_csv(folderexp+'uracil+c6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_f6=pd.read_csv(folderexp+'uracil+f6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_o6=pd.read_csv(folderexp+'uracil+o6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_of8=pd.read_csv(folderexp+'uracil+o8f8_ref14-15.dat',sep=' ',delimiter='\s+',header=None)

# %%
A_e['Ep']=A_e['Ee']*1.8375597
C_e['Ep']=C_e['Ee']*1.8375597
G_e['Ep']=G_e['Ee']*1.8375597

# %%
iAe=len(A_e[A_e['Ep']>500])
iCe=len(C_e[C_e['Ep']<500])
iGe=len(G_e[G_e['Ep']>500])
iTe=len(T_e[T_e['Ep']>500])
iTHFe19=len(THF_e19[THF_e19['Ep']>500])

# %%
dum=PS1int[convkeV(PS1int['ENERGY']) < 100.]
ie100=len(dum)

# %%
itickssize=28
imolsize=30
ilabelsize=30
ilegsize=26

# %%
iwidth=2.5
xmin=60.
xmax=10000
ymin=2.
ymax=200.
xtext=250.
ytext=6.

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)
plt.text(70, PS1int['SLADENINA'][ie100]*convMb*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLADENINA'][0]*convMb*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLADENINA'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLADENINA'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLADENINA'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLADENINA'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convMb,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convMb*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLADENINA'][ie100:]*convMb/2**2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLADENINA'][ie100:]*convMb/4**2,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLADENINA'][ie100:]*convMb/6**2,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLADENINA'][ie100:]*convMb/8**2,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experimentos #
Ap, = ax1.plot(A_p['E'],A_p['CS']/45*100,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Ae, = ax1.plot(A_e['Ep'][0:iAe],A_e['CS'][0:iAe]/45*100,color='tab:gray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=6,linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z$^2$ (Mb)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(which='major', labelsize=itickssize,length=8);
ax1.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)


### CITOSINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)
plt.text(70, PS1int['SLCITOSINA'][ie100]*convMb*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLCITOSINA'][0]*convMb*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLCITOSINA'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLCITOSINA'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLCITOSINA'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLCITOSINA'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convMb*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLCITOSINA'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLCITOSINA'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLCITOSINA'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLCITOSINA'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][iCe:],C_e['CS'][iCe:]/37*100,color='tab:gray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax2.tick_params(which='major', labelsize=itickssize,length=8);
ax2.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)
plt.text(70, PS1int['SLGUANINA'][ie100]*convMb*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLGUANINA'][0]*convMb*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLGUANINA'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLGUANINA'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLGUANINA'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLGUANINA'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convMb*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLGUANINA'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLGUANINA'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLGUANINA'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLGUANINA'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:iGe],G_e['CS'][0:iGe]/49*100,color='tab:gray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax3.tick_params(which='major', labelsize=itickssize,length=8);
ax3.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### TIMINA ###
ax4 = plt.subplot(224)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
plt.text(70, PS1int['SLTIMINA'][ie100]*convMb*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLTIMINA'][0]*convMb*0.85, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLTIMINA'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLTIMINA'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLTIMINA'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLTIMINA'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convMb*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLTIMINA'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLTIMINA'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLTIMINA'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLTIMINA'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:iTe],T_e['CS'][0:iTe]/42*100,color='tab:gray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

plt.xlabel("Impact Energy (keV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(which='major', labelsize=itickssize,length=8);
ax4.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn1.eps',bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=60.
xmax=10000
ymin=2.
ymax=200.
xtext=250.
ytext=6.

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### URACILO ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)
plt.text(70, PS1int['SLURACILO'][ie100]*convMb*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLURACILO'][0]*convMb*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLURACILO'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLURACILO'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLURACILO'][ie100]*convMb*1./6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLURACILO'][ie100]*convMb*0.65/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convMb,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convMb*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLURACILO'][ie100:]*convMb/2**2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLURACILO'][ie100:]*convMb/4**2,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLURACILO'][ie100:]*convMb/6**2,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLURACILO'][ie100:]*convMb/8**2,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experiments
Up, = ax1.plot(U_p['E'],U_p['CS']/36*100,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc4, = ax1.plot(U_c4[1],U_c4[3]/36*100,color=co_be,marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc6, = ax1.plot(U_c6[1],U_c6[2]/36*100,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uo6, = ax1.plot(U_o6[1],U_o6[3]/36*100,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uf6, = ax1.plot(U_f6[1],U_f6[2]/36*100,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uof8, = ax1.plot(U_of8[0],U_of8[1]/36*100,color=co_o,marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z$^2$ (Mb)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(which='major', labelsize=itickssize,length=8);
ax1.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)

### PYRIMIDINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)
plt.text(70, PS3int['SLC4H4N2'][ie100]*convMb*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS3int['SLC4H4N2'][ie100]*convMb*0.65, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS3int['SLC4H4N2'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS3int['SLC4H4N2'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS3int['SLC4H4N2'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS3int['SLC4H4N2'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convMb*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H4N2'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H4N2'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H4N2'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H4N2'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
PYRp, = ax2.plot(PYR_p['E'][2:],PYR_p['au'][2:]/28*convMb,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
PYRe, = ax2.plot(bug17['Ep(keV)'],bug17['e+PY']/28*100,color='tab:gray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax2.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax2.tick_params(which='major', labelsize=itickssize,length=8);
ax2.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)
plt.text(70, PS3int['SLC4H8O1'][ie100]*convMb*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS3int['SLC4H8O1'][ie100]*convMb*0.5, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS3int['SLC4H8O1'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS3int['SLC4H8O1'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS3int['SLC4H8O1'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS3int['SLC4H8O1'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convMb*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H8O1'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H8O1'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H8O1'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H8O1'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
THFp, = ax3.plot(THF_p['Ep'],THF_p['au']/28*convMb,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe09, = ax3.plot(THF_e09['Ep(kev)'],THF_e09['CS']/28*100,color='tab:gray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe17, = ax3.plot(bug17['Ep(keV)'],bug17['e+THF']/28*100,color='tab:gray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe19, = ax3.plot(convkeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convMb,color='tab:gray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax3.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax3.tick_params(which='major', labelsize=itickssize,length=8);
ax3.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### DNA BACKBONE ###
ax4 = plt.subplot(224)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
plt.text(70, PS1int['SLBACKBONE'][ie100]*convMb*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(70, APS1int['SLBACKBONE'][ie100]*convMb*0.6, r'$-1$',color=co_p,fontsize=22)
plt.text(70, HeS1int['SLBACKBONE'][ie100]*convMb*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(70, BeS1int['SLBACKBONE'][ie100]*convMb*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(70, CS1int['SLBACKBONE'][ie100]*convMb*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(70, OS1int['SLBACKBONE'][ie100]*convMb*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convMb,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convMb*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLBACKBONE'][ie100:]*convMb/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLBACKBONE'][ie100:]*convMb/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLBACKBONE'][ie100:]*convMb/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLBACKBONE'][ie100:]*convMb/8**2,co_o,linewidth=iwidth, label='_nolegend_')

plt.xlabel("Impact Energy (keV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(which='major', labelsize=itickssize,length=8);
ax4.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn2.eps',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plot interpolated data from 0.1 to 10 MeV

# %%
ymin=2
ymax=2000
xmin=60.
xmax=convkeV(20.)
xtext=5500
ytext=1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
plt.text(xtext, ytext, '(a)',fontsize=imolsize)
plt.text(130, 5, 'Toburen rule',fontsize=imolsize)
plt.text(65, PNS1int['ADENINA'][ie100]*convMb*1., r'$+1$',color=co_p,fontsize=26)
plt.text(65, HeNS1int['ADENINA'][ie100]*convMb*1., r'$+2$',color=co_he,fontsize=26)
plt.text(65, BeNS1int['ADENINA'][ie100]*convMb*0.9, r'$+4$',color=co_be,fontsize=26)
plt.text(65, CNS1int['ADENINA'][ie100]*convMb*1.2, r'$+6$',color=co_c,fontsize=26)
plt.text(65, ONS1int['ADENINA'][ie100]*convMb*1.7, r'$+8$',color=co_o,fontsize=26)

pline=plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int['ADENINA'][ie100:]*convMb,co_p,linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(convkeV(HeNS1int['ENERGY'][ie100:]),HeNS1int['ADENINA'][ie100:]*convMb,co_he,linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(convkeV(BeNS1int['ENERGY'][ie100:]),BeNS1int['ADENINA'][ie100:]*convMb,co_be,linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(convkeV(CNS1int['ENERGY'][ie100:]),CNS1int['ADENINA'][ie100:]*convMb,co_c,linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(convkeV(ONS1int['ENERGY'][ie100:]),ONS1int['ADENINA'][ie100:]*convMb,co_o,linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int[i][ie100:]*convMb,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS1int['ENERGY'][ie100:]),HeNS1int[i][ie100:]*convMb,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS1int['ENERGY'][ie100:]),BeNS1int[i][ie100:]*convMb,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS1int['ENERGY'][ie100:]),CNS1int[i][ie100:]*convMb,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS1int['ENERGY'][ie100:]),ONS1int[i][ie100:]*convMb,co_o,linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(convkeV(PNS2int['ENERGY'][ie100:]),PNS2int[i][ie100:]*convMb,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS2int['ENERGY'][ie100:]),HeNS2int[i][ie100:]*convMb,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS2int['ENERGY'][ie100:]),BeNS2int[i][ie100:]*convMb,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS2int['ENERGY'][ie100:]),CNS2int[i][ie100:]*convMb,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS2int['ENERGY'][ie100:]),ONS2int[i][ie100:]*convMb,co_o,linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(convkeV(PNS3int['ENERGY'][ie100:]),PNS3int[i][ie100:]*convMb,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS3int['ENERGY'][ie100:]),HeNS3int[i][ie100:]*convMb,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS3int['ENERGY'][ie100:]),BeNS3int[i][ie100:]*convMb,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS3int['ENERGY'][ie100:]),CNS3int[i][ie100:]*convMb,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS3int['ENERGY'][ie100:]),ONS3int[i][ie100:]*convMb,co_o,linewidth=1,label='_nolegend_')

ax1.tick_params(which='major', labelsize=itickssize,length=8);
ax1.tick_params(which='minor', length=6)
plt.xlabel("Impact Energy (keV/amu)", fontsize=ilabelsize,labelpad=5,position=(1,0))
plt.ylabel("Ionization Cross Section (Mb)", fontsize=ilabelsize,labelpad=5)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=ilegsize,ncol=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

ax2 = plt.subplot(122)
plt.text(130, 5, 'Present work',fontsize=imolsize)
plt.text(xtext, ytext, '(b)',fontsize=imolsize)
plt.text(65, PS1int['SLADENINA'][ie100]*convMb*1., r'$+1$',color=co_p,fontsize=26)
plt.text(65, HeS1int['SLADENINA'][ie100]*convMb*1., r'$+2$',color=co_he,fontsize=26)
plt.text(65, BeS1int['SLADENINA'][ie100]*convMb*0.9, r'$+4$',color=co_be,fontsize=26)
plt.text(65, CS1int['SLADENINA'][ie100]*convMb*1.2, r'$+6$',color=co_c,fontsize=26)
plt.text(65, OS1int['SLADENINA'][ie100]*convMb*1.7, r'$+8$',color=co_o,fontsize=26)

for i in head_adn[1:]:
    plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int[i][ie100:]*convMb,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int[i][ie100:]*convMb,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int[i][ie100:]*convMb,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int[i][ie100:]*convMb,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int[i][ie100:]*convMb,co_o,linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convkeV(PS2int['ENERGY'][ie100:]),PS2int[i][ie100:]*convMb,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS2int['ENERGY'][ie100:]),HeS2int[i][ie100:]*convMb,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS2int['ENERGY'][ie100:]),BeS2int[i][ie100:]*convMb,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS2int['ENERGY'][ie100:]),CS2int[i][ie100:]*convMb,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS2int['ENERGY'][ie100:]),OS2int[i][ie100:]*convMb,co_o,linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int[i][ie100:]*convMb,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int[i][ie100:]*convMb,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int[i][ie100:]*convMb,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int[i][ie100:]*convMb,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int[i][ie100:]*convMb,co_o,linewidth=1, label='_nolegend_')
plt.axvline(2000,linestyle='--',color='tab:gray',linewidth=1)
# experiments
Ap, = ax2.plot(A_p['E'],A_p['CS']/45*100,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Up, = ax2.plot(U_p['E'],U_p['CS']/36*100,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRp, = ax2.plot(PYR_p['E'][2:],PYR_p['au'][2:]/28*convMb,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRe, = ax2.plot(bug17['Ep(keV)'],bug17['e+PY']/28*100,color='tab:gray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFp, = ax2.plot(THF_p['Ep'],THF_p['au']/28*convMb,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe09, = ax2.plot(THF_e09['Ep(kev)'],THF_e09['CS']/28*100,color='tab:gray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe17, = ax2.plot(bug17['Ep(keV)'],bug17['e+THF']/28*100,color='tab:gray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe19, = ax2.plot(convkeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convMb,color='tab:gray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

ax2.tick_params(which='major', labelsize=itickssize,length=8);
ax2.tick_params(which='minor', length=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()

# %%
PNS2int.head()
# Out:
#    ENERGY       CH4      C2H2      C2H4      C2H6      C6H6
# 0     1.0  2.478000  2.076000  2.255000  2.382000  2.076000
# 1     1.1  3.174163  2.705252  2.913843  3.062181  2.705252
# 2     1.2  3.687417  3.178814  3.404924  3.565990  3.178814
# 3     1.3  4.038929  3.514113  3.747333  3.913692  3.514113
# 4     1.4  4.249870  3.728581  3.960160  4.125554  3.728581

# %%
PNS3int.head()
# Out:
#    ENERGY    C4H4N2    C2H7N1    C1H5N1    C5H5N1    C4H8O1
# 0     1.0  1.652000  2.026000  1.928000  1.864000  1.902000
# 1     1.1  2.196365  2.636281  2.517321  2.451136  2.481319
# 2     1.2  2.613956  3.094366  2.961175  2.896890  2.918451
# 3     1.3  2.918443  3.417362  3.275808  3.216836  3.229230
# 4     1.4  3.123492  3.622379  3.477471  3.426546  3.429492

# %%
PNS1int.head()
# Out:
#    ENERGY   URACILO   ADENINA    TIMINA  CITOSINA   GUANINA  BACKBONE  \
# 0     1.0  1.320000  1.439000  1.437000  1.421000  1.338000  1.468000
# 1     1.1  1.783505  1.941079  1.924579  1.910568  1.814274  1.939927
# 2     1.2  2.144978  2.330821  2.302049  2.290388  2.185926  2.303199
# 3     1.3  2.415006  2.620012  2.581037  2.571987  2.463792  2.569427
# 4     1.4  2.604174  2.820440  2.773168  2.766887  2.658707  2.750220
#
#      DRYDNA
# 0  1.401000
# 1  1.871230
# 2  2.235649
# 3  2.505393
# 4  2.691596

# %% [markdown]
# # Ionization cross section in terms of $n_e$

# %%
cross_ne=pd.read_csv("data_recta.dat",sep=' ',delimiter='\s+',header='infer',skiprows=(1,2,3))

# %%
expH_ne=pd.read_csv("expH_recta.dat",sep=' ',delimiter='\s+',header='infer')

# %%
expe_ne=pd.read_csv("expe_recta.dat",sep=' ',delimiter='\s+',header='infer')

# %%
fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(111)
plt.plot(cross_ne['Ne'],cross_ne['0.5MeV']*convMb,color='goldenrod',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='0.5 MeV')
plt.plot(cross_ne['Ne'],cross_ne['1MeV']*convMb,color='olivedrab',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='1 MeV')
plt.plot(cross_ne['Ne'],cross_ne['2MeV']*convMb,color='cadetblue',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='2 MeV')
plt.plot(expH_ne['Ne'][0:2],expH_ne['a.u.'][0:2]*convMb,marker='*',markersize=22,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][2:4],expH_ne['a.u.'][2:4]*convMb,marker='o',markersize=14,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][4:8],expH_ne['a.u.'][4:8]*convMb,marker='^',markersize=16,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][8],expH_ne['a.u.'][8]*convMb,marker='v',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][9:12],expH_ne['a.u.'][9:12]*convMb,marker='^',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][12:],expH_ne['a.u.'][12:]*convMb,marker='o',markersize=14,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')

plt.xlabel("$n_e$", fontsize=ilabelsize,labelpad=5)
plt.ylabel("Ionization Cross Section (Mb)", fontsize=ilabelsize,labelpad=5)

ax1.yaxis.set_major_locator(mticker.MultipleLocator(250));
ax1.yaxis.set_minor_locator(mticker.MultipleLocator(50));
ax1.xaxis.set_major_locator(mticker.MultipleLocator(5));
ax1.xaxis.set_minor_locator(mticker.MultipleLocator(1));
ax1.tick_params(which='major', labelsize=itickssize,length=8);
ax1.tick_params(which='minor', length=6)
ax1.legend(loc='upper left',fontsize=ilegsize,ncol=1,handletextpad=0.5,labelspacing=0.2,frameon=False)

plt.text(1.2, 150, r'H$_2$',fontsize=28)
plt.text(2.5, 350, r'H$_2$O',fontsize=28)
ax1.annotate("", xy=(5.75, 235), xytext=(4.2, 340),arrowprops=dict(arrowstyle="-|>"))
plt.text(5, 550, r'NH$_3$',fontsize=28)
ax1.annotate("", xy=(6.9, 270), xytext=(6.2, 540),arrowprops=dict(arrowstyle="-|>"))
plt.text(8, 450, r'CH$_4$',fontsize=28)
ax1.annotate("", xy=(8.1, 300), xytext=(9, 440),arrowprops=dict(arrowstyle="-|>"))
plt.text(11, 700, r'CH$_5$N',fontsize=28)
ax1.annotate("", xy=(13, 465), xytext=(12.6, 695),arrowprops=dict(arrowstyle="-|>"))
plt.text(17, 750, r'C$_2$H$_7$N',fontsize=28)
plt.text(25, 1000, 'THF',fontsize=28)
plt.text(28.5, 1100, r'C$_6$H$_6$',fontsize=28)
plt.text(32.2, 1320, 'Uracil',fontsize=28)
ax1.annotate("", xy=(35.7, 1200), xytext=(34.5, 1310),arrowprops=dict(arrowstyle="-|>"))
plt.text(37.5, 1520, 'Thymine',fontsize=28)
ax1.annotate("", xy=(41.7, 1400), xytext=(40, 1500),arrowprops=dict(arrowstyle="-|>"))

plt.text(24, 70, 'Pyrimidine',fontsize=28)
ax1.annotate("", xy=(27.6, 240), xytext=(26.9, 130),arrowprops=dict(arrowstyle="-|>"))
plt.text(36, 100, 'Cytosine',fontsize=28)
ax1.annotate("", xy=(37.2, 350), xytext=(38.5, 155),arrowprops=dict(arrowstyle="-|>"))
plt.text(41.5, 230, 'Adenine',fontsize=28)
ax1.annotate("", xy=(44.9, 430), xytext=(44, 295),arrowprops=dict(arrowstyle="-|>"))
plt.text(45.5, 80, 'Guanine',fontsize=28)
ax1.annotate("", xy=(48.8, 460), xytext=(48, 150),arrowprops=dict(arrowstyle="-|>"))

plt.savefig("../scale_ne.eps",bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=0.06
xmax=10
ymin=2./100
ymax=200./100
xtext=0.250
ytext=6./100
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)
plt.text(icharge, PS1int['SLADENINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLADENINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLADENINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLADENINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLADENINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLADENINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLADENINA'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLADENINA'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLADENINA'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLADENINA'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experimentos #
Ap, = ax1.plot(A_p['E']/1000.,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Ae, = ax1.plot(A_e['Ep'][0:iAe]/1000.,A_e['CS'][0:iAe]/45,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=6,linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z$^2$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### CITOSINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)
plt.text(icharge, PS1int['SLCITOSINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLCITOSINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLCITOSINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLCITOSINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLCITOSINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLCITOSINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convcm2*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLCITOSINA'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLCITOSINA'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLCITOSINA'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLCITOSINA'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][iCe:]/1000,C_e['CS'][iCe:]/37,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)
plt.text(icharge, PS1int['SLGUANINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLGUANINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLGUANINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLGUANINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLGUANINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLGUANINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLGUANINA'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLGUANINA'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLGUANINA'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLGUANINA'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:iGe]/1000,G_e['CS'][0:iGe]/49,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### TIMINA ###
ax4 = plt.subplot(224)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
plt.text(icharge, PS1int['SLTIMINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLTIMINA'][0]*convcm2*0.85, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLTIMINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLTIMINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLTIMINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLTIMINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convcm2*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLTIMINA'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLTIMINA'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLTIMINA'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLTIMINA'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:iTe]/1000,T_e['CS'][0:iTe]/42,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

plt.xlabel("Impact Energy (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn1.eps',bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=0.06
xmax=10
ymin=2./100
ymax=200./100
xtext=0.250
ytext=6./100
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### URACILO ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)
plt.text(icharge, PS1int['SLURACILO'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLURACILO'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLURACILO'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLURACILO'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLURACILO'][ie100]*convcm2*1./6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLURACILO'][ie100]*convcm2*0.65/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convcm2*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLURACILO'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLURACILO'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLURACILO'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLURACILO'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experiments
Up, = ax1.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc4, = ax1.plot(U_c4[1]/1000,U_c4[3]/36,color=co_be,marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc6, = ax1.plot(U_c6[1]/1000,U_c6[2]/36,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uo6, = ax1.plot(U_o6[1]/1000,U_o6[3]/36,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uf6, = ax1.plot(U_f6[1]/1000,U_f6[2]/36,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uof8, = ax1.plot(U_of8[0]/1000,U_of8[1]/36,color=co_o,marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z$^2$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### PYRIMIDINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)
plt.text(icharge, PS3int['SLC4H4N2'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS3int['SLC4H4N2'][ie100]*convcm2*0.65, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS3int['SLC4H4N2'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS3int['SLC4H4N2'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS3int['SLC4H4N2'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS3int['SLC4H4N2'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convcm2*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H4N2'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H4N2'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H4N2'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H4N2'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
PYRp, = ax2.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
PYRe, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax2.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)
plt.text(icharge, PS3int['SLC4H8O1'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS3int['SLC4H8O1'][ie100]*convcm2*0.5, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS3int['SLC4H8O1'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS3int['SLC4H8O1'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS3int['SLC4H8O1'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS3int['SLC4H8O1'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convcm2*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H8O1'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H8O1'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H8O1'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H8O1'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
THFp, = ax3.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe09, = ax3.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe17, = ax3.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe19, = ax3.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax3.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### DNA BACKBONE ###
ax4 = plt.subplot(224)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
plt.text(icharge, PS1int['SLBACKBONE'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
plt.text(icharge, APS1int['SLBACKBONE'][ie100]*convcm2*0.6, r'$-1$',color=co_p,fontsize=22)
plt.text(icharge, HeS1int['SLBACKBONE'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
plt.text(icharge, BeS1int['SLBACKBONE'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
plt.text(icharge, CS1int['SLBACKBONE'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
plt.text(icharge, OS1int['SLBACKBONE'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convcm2*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLBACKBONE'][ie100:]*convcm2/2**2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLBACKBONE'][ie100:]*convcm2/4**2,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int['SLBACKBONE'][ie100:]*convcm2/6**2,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int['SLBACKBONE'][ie100:]*convcm2/8**2,co_o,linewidth=iwidth, label='_nolegend_')

plt.xlabel("Impact Energy (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn2.eps',bbox_inches='tight')
plt.show()

# %%
ymin=0.02
ymax=20
xmin=convMeV(1.5)
xmax=convMeV(20.)
xtext=5
ytext=10
icharge=65/1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
plt.text(xtext, ytext, '(a)',fontsize=imolsize)
plt.text(0.13, 0.05, 'Toburen rule',fontsize=imolsize)
plt.text(icharge, PNS1int['ADENINA'][ie100]*convcm2*1., r'$+1$',color=co_p,fontsize=26)
plt.text(icharge, HeNS1int['ADENINA'][ie100]*convcm2*1., r'$+2$',color=co_he,fontsize=26)
plt.text(icharge, BeNS1int['ADENINA'][ie100]*convcm2*0.9, r'$+4$',color=co_be,fontsize=26)
plt.text(icharge, CNS1int['ADENINA'][ie100]*convcm2*1.2, r'$+6$',color=co_c,fontsize=26)
plt.text(icharge, ONS1int['ADENINA'][ie100]*convcm2*1.7, r'$+8$',color=co_o,fontsize=26)

pline=plt.plot(convMeV(PNS1int['ENERGY'][ie100:]),PNS1int['ADENINA'][ie100:]*convcm2,co_p,linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(convMeV(HeNS1int['ENERGY'][ie100:]),HeNS1int['ADENINA'][ie100:]*convcm2,co_he,linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(convMeV(BeNS1int['ENERGY'][ie100:]),BeNS1int['ADENINA'][ie100:]*convcm2,co_be,linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(convMeV(CNS1int['ENERGY'][ie100:]),CNS1int['ADENINA'][ie100:]*convcm2,co_c,linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(convMeV(ONS1int['ENERGY'][ie100:]),ONS1int['ADENINA'][ie100:]*convcm2,co_o,linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(convMeV(PNS1int['ENERGY'][ie100:]),PNS1int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS1int['ENERGY'][ie100:]),HeNS1int[i][ie100:]*convcm2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS1int['ENERGY'][ie100:]),BeNS1int[i][ie100:]*convcm2,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS1int['ENERGY'][ie100:]),CNS1int[i][ie100:]*convcm2,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS1int['ENERGY'][ie100:]),ONS1int[i][ie100:]*convcm2,co_o,linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(convMeV(PNS2int['ENERGY'][ie100:]),PNS2int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS2int['ENERGY'][ie100:]),HeNS2int[i][ie100:]*convcm2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS2int['ENERGY'][ie100:]),BeNS2int[i][ie100:]*convcm2,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS2int['ENERGY'][ie100:]),CNS2int[i][ie100:]*convcm2,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS2int['ENERGY'][ie100:]),ONS2int[i][ie100:]*convcm2,co_o,linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(convMeV(PNS3int['ENERGY'][ie100:]),PNS3int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS3int['ENERGY'][ie100:]),HeNS3int[i][ie100:]*convcm2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS3int['ENERGY'][ie100:]),BeNS3int[i][ie100:]*convcm2,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS3int['ENERGY'][ie100:]),CNS3int[i][ie100:]*convcm2,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS3int['ENERGY'][ie100:]),ONS3int[i][ie100:]*convcm2,co_o,linewidth=1,label='_nolegend_')

ax1.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlabel("Impact Energy (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(1,0))
plt.ylabel(r"$\sigma_e$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=ilegsize,ncol=6)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

ax2 = plt.subplot(122)
plt.text(0.13, 0.05, 'Present work',fontsize=imolsize)
plt.text(xtext, ytext, '(b)',fontsize=imolsize)
plt.text(icharge, PS1int['SLADENINA'][ie100]*convcm2*1., r'$+1$',color=co_p,fontsize=26)
plt.text(icharge, HeS1int['SLADENINA'][ie100]*convcm2*1., r'$+2$',color=co_he,fontsize=26)
plt.text(icharge, BeS1int['SLADENINA'][ie100]*convcm2*0.9, r'$+4$',color=co_be,fontsize=26)
plt.text(icharge, CS1int['SLADENINA'][ie100]*convcm2*1.2, r'$+6$',color=co_c,fontsize=26)
plt.text(icharge, OS1int['SLADENINA'][ie100]*convcm2*1.7, r'$+8$',color=co_o,fontsize=26)

for i in head_adn[1:]:
    plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS1int['ENERGY'][ie100:]),HeS1int[i][ie100:]*convcm2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS1int['ENERGY'][ie100:]),BeS1int[i][ie100:]*convcm2,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS1int['ENERGY'][ie100:]),CS1int[i][ie100:]*convcm2,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS1int['ENERGY'][ie100:]),OS1int[i][ie100:]*convcm2,co_o,linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convMeV(PS2int['ENERGY'][ie100:]),PS2int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS2int['ENERGY'][ie100:]),HeS2int[i][ie100:]*convcm2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS2int['ENERGY'][ie100:]),BeS2int[i][ie100:]*convcm2,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS2int['ENERGY'][ie100:]),CS2int[i][ie100:]*convcm2,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS2int['ENERGY'][ie100:]),OS2int[i][ie100:]*convcm2,co_o,linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS3int['ENERGY'][ie100:]),HeS3int[i][ie100:]*convcm2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS3int['ENERGY'][ie100:]),BeS3int[i][ie100:]*convcm2,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS3int['ENERGY'][ie100:]),CS3int[i][ie100:]*convcm2,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS3int['ENERGY'][ie100:]),OS3int[i][ie100:]*convcm2,co_o,linewidth=1, label='_nolegend_')
# plt.axvline(2,linestyle='--',color='dimgray',linewidth=1)
# experiments
Ap, = ax2.plot(A_p['E']/1000,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Up, = ax2.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRp, = ax2.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRe, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFp, = ax2.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe09, = ax2.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe17, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe19, = ax2.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

# plt.ylabel(r"$\sigma_e'$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)
# ax2.yaxis.set_label_position("right")
# ax2.yaxis.tick_right()
ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax2.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax2.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(111)
plt.plot(cross_ne['Ne'],cross_ne['0.5MeV']*convcm2,color='goldenrod',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='0.5 MeV')
plt.plot(cross_ne['Ne'],cross_ne['1MeV']*convcm2,color='olivedrab',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='1 MeV')
plt.plot(cross_ne['Ne'],cross_ne['2MeV']*convcm2,color='cadetblue',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='2 MeV')
plt.plot(expH_ne['Ne'][0:2],expH_ne['a.u.'][0:2]*convcm2,marker='*',markersize=22,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][2:4],expH_ne['a.u.'][2:4]*convcm2,marker='o',markersize=14,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][4:8],expH_ne['a.u.'][4:8]*convcm2,marker='^',markersize=16,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][8],expH_ne['a.u.'][8]*convcm2,marker='v',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][9:12],expH_ne['a.u.'][9:12]*convcm2,marker='^',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][12:],expH_ne['a.u.'][12:]*convcm2,marker='o',markersize=14,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')

plt.xlabel("$n_e'$", fontsize=ilabelsize,labelpad=5)
plt.ylabel("Ionization Cross Section ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)

ax1.yaxis.set_major_locator(mticker.MultipleLocator(5));
ax1.yaxis.set_minor_locator(mticker.MultipleLocator(1));
ax1.xaxis.set_major_locator(mticker.MultipleLocator(5));
ax1.xaxis.set_minor_locator(mticker.MultipleLocator(1));
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
ax1.legend(loc='upper left',fontsize=ilegsize,ncol=1,handletextpad=0.5,labelspacing=0.2,frameon=False)

plt.text(1.2, 150/100, r'H$_2$',fontsize=28)
plt.text(2.5, 350/100, r'H$_2$O',fontsize=28)
ax1.annotate("", xy=(5.75, 235/100), xytext=(4.2, 340/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(5, 550/100, r'NH$_3$',fontsize=28)
ax1.annotate("", xy=(6.9, 270/100), xytext=(6.2, 540/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(8, 450/100, r'CH$_4$',fontsize=28)
ax1.annotate("", xy=(8.1, 300/100), xytext=(9, 440/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(11, 700/100, r'CH$_5$N',fontsize=28)
ax1.annotate("", xy=(13, 465/100), xytext=(12.6, 695/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(17, 750/100, r'C$_2$H$_7$N',fontsize=28)
plt.text(25, 1000/100, 'THF',fontsize=28)
plt.text(28.5, 1100/100, r'C$_6$H$_6$',fontsize=28)
plt.text(32.2, 1320/100, 'Uracil',fontsize=28)
ax1.annotate("", xy=(35.7, 1200/100), xytext=(34.5, 1310/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(37.5, 1520/100, 'Thymine',fontsize=28)
ax1.annotate("", xy=(41.7, 1400/100), xytext=(40, 1500/100),arrowprops=dict(arrowstyle="-|>"))

plt.text(24, 70/100, 'Pyrimidine',fontsize=28)
ax1.annotate("", xy=(27.6, 240/100), xytext=(26.9, 130/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(36, 100/100, 'Cytosine',fontsize=28)
ax1.annotate("", xy=(37.2, 350/100), xytext=(38.5, 155/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(41.5, 230/100, 'Adenine',fontsize=28)
ax1.annotate("", xy=(44.9, 430/100), xytext=(44, 295/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(45.5, 80/100, 'Guanine',fontsize=28)
ax1.annotate("", xy=(48.8, 460/100), xytext=(48, 150/100),arrowprops=dict(arrowstyle="-|>"))

plt.savefig("../scale_ne.eps",bbox_inches='tight')
plt.show()

# %% [markdown]
# # Test reviewers

# %%
ymin=2
ymax=2000
xmin=60.
xmax=convkeV(20.)
xtext=5500
ytext=1000

fig = plt.figure(figsize=(18,9))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
ax1 = plt.subplot(121)
plt.text(130, 5, 'Toburen rule',fontsize=imolsize)
plt.text(130, 5, 'Toburen rule',fontsize=imolsize)
plt.plot(convkeV(PNS2int['ENERGY'][ie100:]),PNS2int['CH4'][ie100:]*convMb,'tab:blue',linewidth=2,label=r'CH$_4$')
plt.plot(convkeV(PNS2int['ENERGY'][ie100:]),PNS2int['C2H4'][ie100:]*convMb,'tab:orange',linewidth=2,label='C$_2$H$_4$')
plt.plot(convkeV(PNS2int['ENERGY'][ie100:]),PNS2int['C6H6'][ie100:]*convMb,'tab:green',linewidth=2,label='C$_6$H$_6$')
plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int['URACILO'][ie100:]*convMb,'tab:purple',linewidth=2,label='C$_4$H$_4$N$_2$O$_2$')
plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int['ADENINA'][ie100:]*convMb,'tab:red',linewidth=2,label='C$_5$H$_5$N$_5$')
plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int['BACKBONE'][ie100:]*convMb,'tab:pink',linewidth=2,label='C$_5$H$_{10}$O$_5$P')

ax1.tick_params(which='major', labelsize=itickssize,length=8);
ax1.tick_params(which='minor', length=6)
plt.xlabel("Impact Energy (keV/amu)", fontsize=ilabelsize,labelpad=5,position=(1,0))
plt.ylabel("Ionization Cross Section (Mb)", fontsize=ilabelsize,labelpad=5)
ax1.legend(loc='best',fontsize=ilegsize,handletextpad=0.5,handlelength=1.,labelspacing=0.1,frameon=False)
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

ax2 = plt.subplot(122)
plt.text(130, 5, 'Present work',fontsize=imolsize)
plt.plot(convkeV(PS2int['ENERGY'][ie100:]),PS2int['SLCH4'][ie100:]*convMb,'tab:blue',linewidth=2,label='CH4')
plt.plot(convkeV(PS2int['ENERGY'][ie100:]),PS2int['SLC2H4'][ie100:]*convMb,'tab:orange',linewidth=2,label='C2H4')
plt.plot(convkeV(PS2int['ENERGY'][ie100:]),PS2int['SLC6H6'][ie100:]*convMb,'tab:green',linewidth=2,label='C6H6')
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convMb,'tab:purple',linewidth=2,label='C4H4N2O2')
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convMb,'tab:red',linewidth=2,label='C5H5N5')
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convMb,'tab:pink',linewidth=2,label='C5H10O5P')

ax2.tick_params(which='major', labelsize=itickssize,length=8);
ax2.tick_params(which='minor', length=6)
plt.yscale('log')
plt.xscale('log')

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig("testmolorder.eps",bbox_inches='tight')
plt.show()

# %%
convMeV(PS1["ENERGY"])
# Out:
# 0      0.0250
# 1      0.0497
# 2      0.1000
# 3      0.2002
# 4      0.2993
# 5      0.4000
# 6      0.4995
# 7      0.6996
# 8      0.9986
# 9      1.9980
# 10     2.9700
# 11     4.9700
# 12     6.9720
# 13    10.0000
# Name: ENERGY, dtype: float64

# %%
i05MeV=6
i1MeV=8
i2MeV=9

# %%
neT=[2,8,8,8,14,20,30,30,30,40,42,48,50,56]

# %%
MeV05=[0,0,0,PNS2["CH4"][i05MeV],PNS3["C1H5N1"][i05MeV],PNS3["C2H7N1"][i05MeV],PNS3["C4H8O1"][i05MeV],
       PNS3["C4H4N2"][i05MeV],PNS2["C6H6"][i05MeV],PNS1["URACILO"][i05MeV],PNS1["CITOSINA"][i05MeV],
       PNS1["TIMINA"][i05MeV],PNS1["ADENINA"][i05MeV],PNS1["GUANINA"][i05MeV]]

# %%
MeV1=[0,0,0,PNS2["CH4"][i1MeV],PNS3["C1H5N1"][i1MeV],PNS3["C2H7N1"][i1MeV],PNS3["C4H8O1"][i1MeV],
      PNS3["C4H4N2"][i1MeV],PNS2["C6H6"][i1MeV],PNS1["URACILO"][i1MeV],PNS1["CITOSINA"][i1MeV],
      PNS1["TIMINA"][i1MeV],PNS1["ADENINA"][i1MeV],PNS1["GUANINA"][i1MeV]]

# %%
MeV2=[0,0,0,PNS2["CH4"][i2MeV],PNS3["C1H5N1"][i2MeV],PNS3["C2H7N1"][i2MeV],PNS3["C4H8O1"][i2MeV],
      PNS3["C4H4N2"][i2MeV],PNS2["C6H6"][i2MeV],PNS1["URACILO"][i2MeV],PNS1["CITOSINA"][i2MeV],
      PNS1["TIMINA"][i2MeV],PNS1["ADENINA"][i2MeV],PNS1["GUANINA"][i2MeV]]

# %%
cross_neT=cross_ne.copy()

# %%
cross_neT=cross_neT.drop(columns=["3MeV","5MeV","7MeV","10MeV"])

# %%
cross_neT["Ne"]=neT

# %%
cross_neT["0.5MeV"]=MeV05*cross_neT["Ne"]
cross_neT["1MeV"]=MeV1*cross_neT["Ne"]
cross_neT["2MeV"]=MeV2*cross_neT["Ne"]

# %%
cross_neT
# Out:
#          Mol  Ne  0.5MeV     1MeV     2MeV
# 0         H2   2   0.000   0.0000   0.0000
# 1        H2O   8   0.000   0.0000   0.0000
# 2        NH3   8   0.000   0.0000   0.0000
# 3        CH4   8   9.672   5.4480   3.0216
# 4       CH5N  14  15.400   8.7696   4.9056
# 5      C2H7N  20  22.580  12.8460   7.1800
# 6      C4H8O  30  33.150  18.9510  10.6290
# 7     C4H4N2  30  32.700  18.8370  10.6260
# 8       C6H6  30  35.610  20.3490  11.4090
# 9   C4H4N2O2  40  39.580  22.9720  13.0360
# 10   C4H5N3O  42  42.840  24.8010  14.0406
# 11  C5H6N2O2  48  48.720  28.1952  15.9600
# 12    C5H5N5  50  52.050  30.1350  17.0600
# 13   C5H5N5O  56  56.504  32.7768  18.5920

# %%
fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(111)
plt.plot(cross_ne['Ne'],cross_ne['0.5MeV']*convcm2,color='goldenrod',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='0.5 MeV')
plt.plot(cross_neT['Ne'][3:],cross_neT['0.5MeV'][3:]*convcm2,color='gray',marker='d',markersize=14,markeredgewidth=1.,linestyle='dotted',linewidth=2,label='_nolegend_')
plt.plot(cross_ne['Ne'],cross_ne['1MeV']*convcm2,color='olivedrab',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='1 MeV')
plt.plot(cross_neT['Ne'][3:],cross_neT['1MeV'][3:]*convcm2,color='gray',marker='d',markersize=14,markeredgewidth=1.,linestyle='dotted',linewidth=2,label='_nolegend_')
plt.plot(cross_ne['Ne'],cross_ne['2MeV']*convcm2,color='cadetblue',marker='s',markersize=12,markeredgewidth=1.,linestyle='--',linewidth=2,label='2 MeV')
plt.plot(cross_neT['Ne'][3:],cross_neT['2MeV'][3:]*convcm2,color='gray',marker='d',markersize=14,markeredgewidth=1.,linestyle='dotted',linewidth=2,label='Toburen')

plt.plot(expH_ne['Ne'][0:2],expH_ne['a.u.'][0:2]*convcm2,marker='*',markersize=22,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][2:4],expH_ne['a.u.'][2:4]*convcm2,marker='o',markersize=14,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][4:8],expH_ne['a.u.'][4:8]*convcm2,marker='^',markersize=16,color='tab:red',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][8],expH_ne['a.u.'][8]*convcm2,marker='v',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][9:12],expH_ne['a.u.'][9:12]*convcm2,marker='^',markersize=16,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')
plt.plot(expH_ne['Ne'][12:],expH_ne['a.u.'][12:]*convcm2,marker='o',markersize=14,markeredgewidth=2,color='tab:red',markerfacecolor='none',linestyle='none',label='_nolegend_')

plt.xlabel("$n_e$", fontsize=ilabelsize,labelpad=5)
plt.ylabel("Ionization Cross Section ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)

ax1.yaxis.set_major_locator(mticker.MultipleLocator(5));
ax1.yaxis.set_minor_locator(mticker.MultipleLocator(1));
ax1.xaxis.set_major_locator(mticker.MultipleLocator(5));
ax1.xaxis.set_minor_locator(mticker.MultipleLocator(1));
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
ax1.legend(loc='upper left',fontsize=ilegsize,ncol=1,handletextpad=0.5,labelspacing=0.2,frameon=False)

plt.text(1.2, 150/100, r'H$_2$',fontsize=28)
plt.text(2.5, 350/100, r'H$_2$O',fontsize=28)
ax1.annotate("", xy=(5.75, 235/100), xytext=(4.2, 340/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(5, 550/100, r'NH$_3$',fontsize=28)
ax1.annotate("", xy=(6.9, 270/100), xytext=(6.2, 540/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(8, 450/100, r'CH$_4$',fontsize=28)
ax1.annotate("", xy=(8.1, 300/100), xytext=(9, 440/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(11, 700/100, r'CH$_5$N',fontsize=28)
ax1.annotate("", xy=(13, 465/100), xytext=(12.6, 695/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(17, 750/100, r'C$_2$H$_7$N',fontsize=28)
plt.text(25, 1000/100, 'THF',fontsize=28)
plt.text(28.5, 1100/100, r'C$_6$H$_6$',fontsize=28)
plt.text(32.2, 1320/100, 'Uracil',fontsize=28)
ax1.annotate("", xy=(35.7, 1200/100), xytext=(34.5, 1310/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(37.5, 1520/100, 'Thymine',fontsize=28)
ax1.annotate("", xy=(41.7, 1400/100), xytext=(40, 1500/100),arrowprops=dict(arrowstyle="-|>"))

plt.text(24, 70/100, 'Pyrimidine',fontsize=28)
ax1.annotate("", xy=(27.6, 240/100), xytext=(26.9, 130/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(36, 100/100, 'Cytosine',fontsize=28)
ax1.annotate("", xy=(37.2, 350/100), xytext=(38.5, 155/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(41.5, 230/100, 'Adenine',fontsize=28)
ax1.annotate("", xy=(44.9, 430/100), xytext=(44, 295/100),arrowprops=dict(arrowstyle="-|>"))
plt.text(45.5, 80/100, 'Guanine',fontsize=28)
ax1.annotate("", xy=(48.8, 460/100), xytext=(48, 150/100),arrowprops=dict(arrowstyle="-|>"))

plt.savefig("testscale_ne.eps",bbox_inches='tight')
plt.show()

# %%
itickssize=28
imolsize=30
ilabelsize=30
ilegsize=26

# %%
iwidth=2.5
xmin=0.06
xmax=10
ymin=2./100
ymax=200./100
xtext=0.07
ytext=10./100
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)
# plt.text(icharge, PS1int['SLADENINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLADENINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLADENINA'][ie100]*convcm2*0.75/2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLADENINA'][ie100]*convcm2*0.85/4, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLADENINA'][ie100]*convcm2*0.8/6, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLADENINA'][ie100]*convcm2*0.8/8, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLADENINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLADENINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLADENINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLADENINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experimentos #
Ap, = ax1.plot(A_p['E']/1000.,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Ae, = ax1.plot(A_e['Ep'][0:iAe]/1000.,A_e['CS'][0:iAe]/45,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=6,linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### CITOSINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)
# plt.text(icharge, PS1int['SLCITOSINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLCITOSINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLCITOSINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLCITOSINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLCITOSINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLCITOSINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convcm2*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLCITOSINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLCITOSINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLCITOSINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLCITOSINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][iCe:]/1000,C_e['CS'][iCe:]/37,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)
# plt.text(icharge, PS1int['SLGUANINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLGUANINA'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLGUANINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLGUANINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLGUANINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLGUANINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLGUANINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLGUANINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLGUANINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLGUANINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:iGe]/1000,G_e['CS'][0:iGe]/49,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### TIMINA ###
ax4 = plt.subplot(224)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
# plt.text(icharge, PS1int['SLTIMINA'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLTIMINA'][0]*convcm2*0.85, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLTIMINA'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLTIMINA'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLTIMINA'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLTIMINA'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convcm2*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLTIMINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLTIMINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLTIMINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLTIMINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:iTe]/1000,T_e['CS'][0:iTe]/42,color='dimgray',marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='none',markevery=4,linestyle=' ',label='e')

plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../Zscaling_adn1.eps',bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=0.06
xmax=10
ymin=2./100
ymax=200./100
xtext=0.07
ytext=10./100
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### URACILO ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)
# plt.text(icharge, PS1int['SLURACILO'][ie100]*convcm2*1.2, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLURACILO'][0]*convcm2*0.8, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLURACILO'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLURACILO'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLURACILO'][ie100]*convcm2*1./6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLURACILO'][ie100]*convcm2*0.65/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convcm2*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLURACILO'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLURACILO'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLURACILO'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLURACILO'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experiments
Up, = ax1.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc4, = ax1.plot(U_c4[1]/1000/4,U_c4[3]/36*4,color=co_be,marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uc6, = ax1.plot(U_c6[1]/1000/6,U_c6[2]/36*6,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uo6, = ax1.plot(U_o6[1]/1000/6,U_o6[3]/36*6,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uf6, = ax1.plot(U_f6[1]/1000/6,U_f6[2]/36*6,color=co_c,marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Uof8, = ax1.plot(U_of8[0]/1000/8,U_of8[1]/36*8,color=co_o,marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='none',linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
# plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### PYRIMIDINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)
# plt.text(icharge, PS3int['SLC4H4N2'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS3int['SLC4H4N2'][ie100]*convcm2*0.65, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS3int['SLC4H4N2'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS3int['SLC4H4N2'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS3int['SLC4H4N2'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS3int['SLC4H4N2'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convcm2*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H4N2'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H4N2'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H4N2'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H4N2'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
PYRp, = ax2.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
PYRe, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax2.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)
# plt.text(icharge, PS3int['SLC4H8O1'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS3int['SLC4H8O1'][ie100]*convcm2*0.5, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS3int['SLC4H8O1'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS3int['SLC4H8O1'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS3int['SLC4H8O1'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS3int['SLC4H8O1'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convcm2*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H8O1'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H8O1'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H8O1'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H8O1'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
THFp, = ax3.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe09, = ax3.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe17, = ax3.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')
THFe19, = ax3.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='p')

ax3.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### DNA BACKBONE ###
ax4 = plt.subplot(224)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
# plt.text(icharge, PS1int['SLBACKBONE'][ie100]*convcm2*1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(icharge, APS1int['SLBACKBONE'][ie100]*convcm2*0.6, r'$-1$',color=co_p,fontsize=22)
# plt.text(icharge, HeS1int['SLBACKBONE'][ie100]*convcm2*0.75/2**2, r'$+2$',color=co_he,fontsize=22)
# plt.text(icharge, BeS1int['SLBACKBONE'][ie100]*convcm2*0.85/4**2, r'$+4$',color=co_be,fontsize=22)
# plt.text(icharge, CS1int['SLBACKBONE'][ie100]*convcm2*0.8/6**2, r'$+6$',color=co_c,fontsize=22)
# plt.text(icharge, OS1int['SLBACKBONE'][ie100]*convcm2*0.8/8**2, r'$+8$',color=co_o,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convcm2*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLBACKBONE'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLBACKBONE'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLBACKBONE'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLBACKBONE'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')

plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('test_adn2.eps',bbox_inches='tight')
plt.show()

# %%
ymin=0.02
ymax=20
xmin=convMeV(1.5)
xmax=convMeV(20.)
xtext=5
ytext=10
icharge=65/1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
# plt.text(xtext, ytext, '(a)',fontsize=imolsize)
plt.text(0.13, 0.05, 'Toburen rule',fontsize=imolsize)
# plt.text(icharge, PNS1int['ADENINA'][ie100]*convcm2*1., r'$+1$',color=co_p,fontsize=26)
# plt.text(icharge, HeNS1int['ADENINA'][ie100]*convcm2*1., r'$+2$',color=co_he,fontsize=26)
# plt.text(icharge, BeNS1int['ADENINA'][ie100]*convcm2*0.9, r'$+4$',color=co_be,fontsize=26)
# plt.text(icharge, CNS1int['ADENINA'][ie100]*convcm2*1.2, r'$+6$',color=co_c,fontsize=26)
# plt.text(icharge, ONS1int['ADENINA'][ie100]*convcm2*1.7, r'$+8$',color=co_o,fontsize=26)

pline=plt.plot(convMeV(PNS1int['ENERGY'][ie100:]),PNS1int['ADENINA'][ie100:]*convcm2,co_p,linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(convMeV(HeNS1int['ENERGY'][ie100:])/2,HeNS1int['ADENINA'][ie100:]*convcm2/2,co_he,linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(convMeV(BeNS1int['ENERGY'][ie100:])/4,BeNS1int['ADENINA'][ie100:]*convcm2/4,co_be,linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(convMeV(CNS1int['ENERGY'][ie100:])/6,CNS1int['ADENINA'][ie100:]*convcm2/6,co_c,linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(convMeV(ONS1int['ENERGY'][ie100:])/8,ONS1int['ADENINA'][ie100:]*convcm2/8,co_o,linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(convMeV(PNS1int['ENERGY'][ie100:]),PNS1int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS1int['ENERGY'][ie100:])/2,HeNS1int[i][ie100:]*convcm2/2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS1int['ENERGY'][ie100:])/4,BeNS1int[i][ie100:]*convcm2/4,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS1int['ENERGY'][ie100:])/6,CNS1int[i][ie100:]*convcm2/6,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS1int['ENERGY'][ie100:])/8,ONS1int[i][ie100:]*convcm2/8,co_o,linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(convMeV(PNS2int['ENERGY'][ie100:]),PNS2int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS2int['ENERGY'][ie100:])/2,HeNS2int[i][ie100:]*convcm2/2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS2int['ENERGY'][ie100:])/4,BeNS2int[i][ie100:]*convcm2/4,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS2int['ENERGY'][ie100:])/6,CNS2int[i][ie100:]*convcm2/6,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS2int['ENERGY'][ie100:])/8,ONS2int[i][ie100:]*convcm2/8,co_o,linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(convMeV(PNS3int['ENERGY'][ie100:]),PNS3int[i][ie100:]*convcm2,co_p,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(HeNS3int['ENERGY'][ie100:])/2,HeNS3int[i][ie100:]*convcm2/2,co_he,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(BeNS3int['ENERGY'][ie100:])/4,BeNS3int[i][ie100:]*convcm2/4,co_be,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(CNS3int['ENERGY'][ie100:])/6,CNS3int[i][ie100:]*convcm2/6,co_c,linewidth=1,label='_nolegend_')
    plt.plot(convMeV(ONS3int['ENERGY'][ie100:])/8,ONS3int[i][ie100:]*convcm2/8,co_o,linewidth=1,label='_nolegend_')

ax1.tick_params(direction='in',which='major', labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlabel("Impact Energy (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(1,0))
plt.ylabel(r"$\sigma_e$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=ilegsize,ncol=6)
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

ax2 = plt.subplot(122)
plt.text(0.13, 0.05, 'Present work',fontsize=imolsize)
# plt.text(xtext, ytext, '(b)',fontsize=imolsize)
# plt.text(icharge, PS1int['SLADENINA'][ie100]*convcm2*1., r'$+1$',color=co_p,fontsize=26)
# plt.text(icharge, HeS1int['SLADENINA'][ie100]*convcm2*1., r'$+2$',color=co_he,fontsize=26)
# plt.text(icharge, BeS1int['SLADENINA'][ie100]*convcm2*0.9, r'$+4$',color=co_be,fontsize=26)
# plt.text(icharge, CS1int['SLADENINA'][ie100]*convcm2*1.2, r'$+6$',color=co_c,fontsize=26)
# plt.text(icharge, OS1int['SLADENINA'][ie100]*convcm2*1.7, r'$+8$',color=co_o,fontsize=26)

for i in head_adn[1:]:
    plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int[i][ie100:]*convcm2/2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int[i][ie100:]*convcm2/4,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int[i][ie100:]*convcm2/6,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int[i][ie100:]*convcm2/8,co_o,linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convMeV(PS2int['ENERGY'][ie100:]),PS2int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS2int['ENERGY'][ie100:])/2,HeS2int[i][ie100:]*convcm2/2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS2int['ENERGY'][ie100:])/4,BeS2int[i][ie100:]*convcm2/4,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS2int['ENERGY'][ie100:])/6,CS2int[i][ie100:]*convcm2/6,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS2int['ENERGY'][ie100:])/8,OS2int[i][ie100:]*convcm2/8,co_o,linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int[i][ie100:]*convcm2/2,co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int[i][ie100:]*convcm2/4,co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int[i][ie100:]*convcm2/6,co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int[i][ie100:]*convcm2/8,co_o,linewidth=1, label='_nolegend_')
# plt.axvline(2,linestyle='--',color='dimgray',linewidth=1)
# experiments
# Ap, = ax2.plot(A_p['E']/1000,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# Up, = ax2.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# PYRp, = ax2.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# PYRe, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# THFp, = ax2.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# THFe09, = ax2.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# THFe17, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
# THFe19, = ax2.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

# plt.ylabel(r"$\sigma_e'$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=5)
# ax2.yaxis.set_label_position("right")
# ax2.yaxis.tick_right()
ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax2.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax2.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

# plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()
