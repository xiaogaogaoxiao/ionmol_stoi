# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
convMb=0.28002*100

# %%
def convkeV(x):
    return 25.0*(x**2)

# %%
folder="~/newmonti/calculos/"

# %%
PS1=pd.read_csv(folder+"P/P_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS2=pd.read_csv(folder+"P/P_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS3=pd.read_csv(folder+"P/P_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS1=pd.read_csv(folder+"He2/He2_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS2=pd.read_csv(folder+"He2/He2_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS3=pd.read_csv(folder+"He2/He2_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS1=pd.read_csv(folder+"Be4/Be4_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS1=pd.read_csv(folder+"C6/C6_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS2=pd.read_csv(folder+"C6/C6_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS3=pd.read_csv(folder+"C6/C6_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS1=pd.read_csv(folder+"O8/O8_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS2=pd.read_csv(folder+"O8/O8_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS3=pd.read_csv(folder+"O8/O8_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
PNS1=pd.read_csv(folder+"P/P_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
PNS2=pd.read_csv(folder+"P/P_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
PNS3=pd.read_csv(folder+"P/P_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
HeNS1=pd.read_csv(folder+"He2/He2_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS2=pd.read_csv(folder+"He2/He2_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS3=pd.read_csv(folder+"He2/He2_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
BeNS1=pd.read_csv(folder+"Be4/Be4_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
CNS1=pd.read_csv(folder+"C6/C6_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
CNS2=pd.read_csv(folder+"C6/C6_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
CNS3=pd.read_csv(folder+"C6/C6_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
ONS1=pd.read_csv(folder+"O8/O8_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
ONS2=pd.read_csv(folder+"O8/O8_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
ONS3=pd.read_csv(folder+"O8/O8_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

# %%
head_adn=list(PS1.columns.values)
head_CHn=list(PS2.columns.values)
head_PYR=list(PS3.columns.values)

# %%
headNS_adn=list(PNS1.columns.values)
headNS_CHn=list(PNS2.columns.values)
headNS_PYR=list(PNS3.columns.values)

# %%
ymin=2
ymax=2000
xmin=convkeV(1.)
xmax=convkeV(20.)
xtext=6000
ytext=1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
pline=plt.plot(PNS1['ENERGY'],PNS1['ADENINA']*convMb,'red',linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(HeNS1['ENERGY'],HeNS1['ADENINA']*convMb,'orange',linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(BeNS1['ENERGY'],BeNS1['ADENINA']*convMb,'forestgreen',linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(CNS1['ENERGY'],CNS1['ADENINA']*convMb,'dodgerblue',linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(ONS1['ENERGY'],ONS1['ADENINA']*convMb,'darkorchid',linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(PNS1['ENERGY'],PNS1[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS1['ENERGY'],HeNS1[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS1['ENERGY'],BeNS1[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS1['ENERGY'],CNS1[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS1['ENERGY'],ONS1[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(PNS2['ENERGY'],PNS2[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS2['ENERGY'],HeNS2[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS2['ENERGY'],BeNS2[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS2['ENERGY'],CNS2[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS2['ENERGY'],ONS2[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(PNS3['ENERGY'],PNS3[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS3['ENERGY'],HeNS3[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS3['ENERGY'],BeNS3[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS3['ENERGY'],CNS3[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS3['ENERGY'],ONS3[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5,position=(1,0))
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.ylabel("Ionization Cross Section (Mb)/Z$^2$", fontsize=28,labelpad=5)
# ax1.legend(loc='lower left',fontsize=26)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=26,ncol=6)
plt.text(xtext, ytext, '(a)',fontsize=28)

ax2 = plt.subplot(122)
for i in head_adn[1:]:
    plt.plot(PS1['ENERGY'],PS1[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS1['ENERGY'],HeS1[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS1['ENERGY'],BeS1[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS1['ENERGY'],CS1[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS1['ENERGY'],OS1[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(PS2['ENERGY'],PS2[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS2['ENERGY'],HeS2[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS2['ENERGY'],BeS2[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS2['ENERGY'],CS2[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS2['ENERGY'],OS2[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(PS3['ENERGY'],PS3[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS3['ENERGY'],HeS3[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS3['ENERGY'],BeS3[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS3['ENERGY'],CS3[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS3['ENERGY'],OS3[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
plt.axvline(2000,linestyle='--',color='tab:gray',linewidth=1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.text(xtext, ytext, '(b)',fontsize=28)
fig.subplots_adjust(hspace=0, wspace=0.125)
plt.show()

# %% [markdown]
# # Convert energy from keV to a.u.

# %%
PS1['ENERGY']=np.sqrt(PS1['ENERGY']/25.)
PS2['ENERGY']=np.sqrt(PS2['ENERGY']/25.)
PS3['ENERGY']=np.sqrt(PS3['ENERGY']/25.)
HeS1['ENERGY']=np.sqrt(HeS1['ENERGY']/25.)
HeS2['ENERGY']=np.sqrt(HeS2['ENERGY']/25.)
HeS3['ENERGY']=np.sqrt(HeS3['ENERGY']/25.)
BeS1['ENERGY']=np.sqrt(BeS1['ENERGY']/25.)
BeS2['ENERGY']=np.sqrt(BeS2['ENERGY']/25.)
BeS3['ENERGY']=np.sqrt(BeS3['ENERGY']/25.)
CS1['ENERGY']=np.sqrt(CS1['ENERGY']/25.)
CS2['ENERGY']=np.sqrt(CS2['ENERGY']/25.)
CS3['ENERGY']=np.sqrt(CS3['ENERGY']/25.)
OS1['ENERGY']=np.sqrt(OS1['ENERGY']/25.)
OS2['ENERGY']=np.sqrt(OS2['ENERGY']/25.)
OS3['ENERGY']=np.sqrt(OS3['ENERGY']/25.)

# %%
PNS1['ENERGY']=np.sqrt(PNS1['ENERGY']/25.)
PNS2['ENERGY']=np.sqrt(PNS2['ENERGY']/25.)
PNS3['ENERGY']=np.sqrt(PNS3['ENERGY']/25.)
HeNS1['ENERGY']=np.sqrt(HeNS1['ENERGY']/25.)
HeNS2['ENERGY']=np.sqrt(HeNS2['ENERGY']/25.)
HeNS3['ENERGY']=np.sqrt(HeNS3['ENERGY']/25.)
BeNS1['ENERGY']=np.sqrt(BeNS1['ENERGY']/25.)
BeNS2['ENERGY']=np.sqrt(BeNS2['ENERGY']/25.)
BeNS3['ENERGY']=np.sqrt(BeNS3['ENERGY']/25.)
CNS1['ENERGY']=np.sqrt(CNS1['ENERGY']/25.)
CNS2['ENERGY']=np.sqrt(CNS2['ENERGY']/25.)
CNS3['ENERGY']=np.sqrt(CNS3['ENERGY']/25.)
ONS1['ENERGY']=np.sqrt(ONS1['ENERGY']/25.)
ONS2['ENERGY']=np.sqrt(ONS2['ENERGY']/25.)
ONS3['ENERGY']=np.sqrt(ONS3['ENERGY']/25.)

# %%
ymin=2
ymax=2000
xmin=1.
xmax=20.
xtext=np.sqrt(6000/25.)
ytext=1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
pline=plt.plot(PNS1['ENERGY'],PNS1['ADENINA']*convMb,'red',linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(HeNS1['ENERGY'],HeNS1['ADENINA']*convMb,'orange',linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(BeNS1['ENERGY'],BeNS1['ADENINA']*convMb,'forestgreen',linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(CNS1['ENERGY'],CNS1['ADENINA']*convMb,'dodgerblue',linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(ONS1['ENERGY'],ONS1['ADENINA']*convMb,'darkorchid',linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(PNS1['ENERGY'],PNS1[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS1['ENERGY'],HeNS1[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS1['ENERGY'],BeNS1[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS1['ENERGY'],CNS1[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS1['ENERGY'],ONS1[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(PNS2['ENERGY'],PNS2[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS2['ENERGY'],HeNS2[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS2['ENERGY'],BeNS2[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS2['ENERGY'],CNS2[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS2['ENERGY'],ONS2[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(PNS3['ENERGY'],PNS3[i]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(HeNS3['ENERGY'],HeNS3[i]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(BeNS3['ENERGY'],BeNS3[i]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(CNS3['ENERGY'],CNS3[i]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(ONS3['ENERGY'],ONS3[i]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Impact Energy (a.u./amu)", fontsize=28,labelpad=5,position=(1,0))
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.ylabel("Ionization Cross Section (Mb)/Z$^2$", fontsize=28,labelpad=5)
# ax1.legend(loc='lower left',fontsize=26)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=26,ncol=6)
plt.text(xtext, ytext, '(a)',fontsize=28)

ax2 = plt.subplot(122)
for i in head_adn[1:]:
    plt.plot(PS1['ENERGY'],PS1[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS1['ENERGY'],HeS1[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS1['ENERGY'],BeS1[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS1['ENERGY'],CS1[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS1['ENERGY'],OS1[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(PS2['ENERGY'],PS2[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS2['ENERGY'],HeS2[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS2['ENERGY'],BeS2[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS2['ENERGY'],CS2[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS2['ENERGY'],OS2[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(PS3['ENERGY'],PS3[i]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(HeS3['ENERGY'],HeS3[i]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(BeS3['ENERGY'],BeS3[i]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(CS3['ENERGY'],CS3[i]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(OS3['ENERGY'],OS3[i]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
plt.axvline(2000,linestyle='--',color='tab:gray',linewidth=1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.text(xtext, ytext, '(b)',fontsize=28)
fig.subplots_adjust(hspace=0, wspace=0.125)

#plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()

# %% [markdown]
# # Make cubic spline interpolation on data

# %%
from scipy import interpolate

def interp_XS(XY,ix,iy,kind):
    x=XY[ix].values
    y=XY[iy].values
    n=len(x)
    spline = interpolate.interp1d(x, y, kind=kind)
    xnew = np.arange(x[0], x[n-1], 0.1)
    ynew = spline(xnew)
    XYnew = pd.DataFrame({ix:xnew, iy:ynew})
    return XYnew

# %%
PS1int=[]
PNS1int=[]
PS1int=interp_XS(PS1,'ENERGY','SLURACILO','cubic')
PNS1int=interp_XS(PNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(PS1,'ENERGY',i,'cubic')
    PS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(PNS1,'ENERGY',i,'cubic')
    PNS1int[i]=dumn1[i]

PS2int=[]
PNS2int=[]
PS2int=interp_XS(PS2,'ENERGY','SLCH4','cubic')
PNS2int=interp_XS(PNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(PS2,'ENERGY',i,'cubic')
    PS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(PNS2,'ENERGY',i,'cubic')
    PNS2int[i]=dumn2[i]

PS3int=[]
PNS3int=[]
PS3int=interp_XS(PS3,'ENERGY','SLC4H4N2','cubic')
PNS3int=interp_XS(PNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(PS3,'ENERGY',i,'cubic')
    PS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(PNS3,'ENERGY',i,'cubic')
    PNS3int[i]=dumn3[i]

# %%
HeS1int=[]
HeNS1int=[]
HeS1int=interp_XS(HeS1,'ENERGY','SLURACILO','cubic')
HeNS1int=interp_XS(HeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(HeS1,'ENERGY',i,'cubic')
    HeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(HeNS1,'ENERGY',i,'cubic')
    HeNS1int[i]=dumn1[i]

HeS2int=[]
HeNS2int=[]
HeS2int=interp_XS(HeS2,'ENERGY','SLCH4','cubic')
HeNS2int=interp_XS(HeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(HeS2,'ENERGY',i,'cubic')
    HeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(HeNS2,'ENERGY',i,'cubic')
    HeNS2int[i]=dumn2[i]

HeS3int=[]
HeNS3int=[]
HeS3int=interp_XS(HeS3,'ENERGY','SLC4H4N2','cubic')
HeNS3int=interp_XS(HeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(HeS3,'ENERGY',i,'cubic')
    HeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(HeNS3,'ENERGY',i,'cubic')
    HeNS3int[i]=dumn3[i]

# %%
BeS1int=[]
BeNS1int=[]
BeS1int=interp_XS(BeS1,'ENERGY','SLURACILO','cubic')
BeNS1int=interp_XS(BeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(BeS1,'ENERGY',i,'cubic')
    BeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(BeNS1,'ENERGY',i,'cubic')
    BeNS1int[i]=dumn1[i]

BeS2int=[]
BeNS2int=[]
BeS2int=interp_XS(BeS2,'ENERGY','SLCH4','cubic')
BeNS2int=interp_XS(BeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(BeS2,'ENERGY',i,'cubic')
    BeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(BeNS2,'ENERGY',i,'cubic')
    BeNS2int[i]=dumn2[i]

BeS3int=[]
BeNS3int=[]
BeS3int=interp_XS(BeS3,'ENERGY','SLC4H4N2','cubic')
BeNS3int=interp_XS(BeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(BeS3,'ENERGY',i,'cubic')
    BeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(BeNS3,'ENERGY',i,'cubic')
    BeNS3int[i]=dumn3[i]

# %%
CS1int=[]
CNS1int=[]
CS1int=interp_XS(CS1,'ENERGY','SLURACILO','cubic')
CNS1int=interp_XS(CNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(CS1,'ENERGY',i,'cubic')
    CS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(CNS1,'ENERGY',i,'cubic')
    CNS1int[i]=dumn1[i]

CS2int=[]
CNS2int=[]
CS2int=interp_XS(CS2,'ENERGY','SLCH4','cubic')
CNS2int=interp_XS(CNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(CS2,'ENERGY',i,'cubic')
    CS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(CNS2,'ENERGY',i,'cubic')
    CNS2int[i]=dumn2[i]

CS3int=[]
CNS3int=[]
CS3int=interp_XS(CS3,'ENERGY','SLC4H4N2','cubic')
CNS3int=interp_XS(CNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(CS3,'ENERGY',i,'cubic')
    CS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(CNS3,'ENERGY',i,'cubic')
    CNS3int[i]=dumn3[i]

# %%
OS1int=[]
ONS1int=[]
OS1int=interp_XS(OS1,'ENERGY','SLURACILO','cubic')
ONS1int=interp_XS(ONS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(OS1,'ENERGY',i,'cubic')
    OS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(ONS1,'ENERGY',i,'cubic')
    ONS1int[i]=dumn1[i]

OS2int=[]
ONS2int=[]
OS2int=interp_XS(OS2,'ENERGY','SLCH4','cubic')
ONS2int=interp_XS(ONS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(OS2,'ENERGY',i,'cubic')
    OS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(ONS2,'ENERGY',i,'cubic')
    ONS2int[i]=dumn2[i]

OS3int=[]
ONS3int=[]
OS3int=interp_XS(OS3,'ENERGY','SLC4H4N2','cubic')
ONS3int=interp_XS(ONS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(OS3,'ENERGY',i,'cubic')
    OS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(ONS3,'ENERGY',i,'cubic')
    ONS3int[i]=dumn3[i]

# %% [markdown]
# # Plot interpolated data from 100keV

# %%
dum=PS1int[convkeV(PS1int['ENERGY']) < 100.]
ie100=len(dum)

# %%
ymin=2
ymax=2000
xmin=100.
xmax=convkeV(20.)
xtext=6000
ytext=1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(121)
pline=plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int['ADENINA'][ie100:]*convMb,'red',linewidth=1.5,label=r'H$^{+}$')
Heline=plt.plot(convkeV(HeNS1int['ENERGY'][ie100:]),HeNS1int['ADENINA'][ie100:]*convMb,'orange',linewidth=1.5,label=r'He$^{+2}$')
Beline=plt.plot(convkeV(BeNS1int['ENERGY'][ie100:]),BeNS1int['ADENINA'][ie100:]*convMb,'forestgreen',linewidth=1.5,label=r'Be$^{+4}$')
Cline=plt.plot(convkeV(CNS1int['ENERGY'][ie100:]),CNS1int['ADENINA'][ie100:]*convMb,'dodgerblue',linewidth=1.5,label=r'C$^{+6}$')
Oline=plt.plot(convkeV(ONS1int['ENERGY'][ie100:]),ONS1int['ADENINA'][ie100:]*convMb,'darkorchid',linewidth=1.5,label=r'O$^{+8}$')
for i in headNS_adn[1:]:
    plt.plot(convkeV(PNS1int['ENERGY'][ie100:]),PNS1int[i][ie100:]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS1int['ENERGY'][ie100:]),HeNS1int[i][ie100:]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS1int['ENERGY'][ie100:]),BeNS1int[i][ie100:]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS1int['ENERGY'][ie100:]),CNS1int[i][ie100:]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS1int['ENERGY'][ie100:]),ONS1int[i][ie100:]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_CHn[1:]:
    plt.plot(convkeV(PNS2int['ENERGY'][ie100:]),PNS2int[i][ie100:]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS2int['ENERGY'][ie100:]),HeNS2int[i][ie100:]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS2int['ENERGY'][ie100:]),BeNS2int[i][ie100:]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS2int['ENERGY'][ie100:]),CNS2int[i][ie100:]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS2int['ENERGY'][ie100:]),ONS2int[i][ie100:]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
for i in headNS_PYR[1:]:
    plt.plot(convkeV(PNS3int['ENERGY'][ie100:]),PNS3int[i][ie100:]*convMb,'red',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(HeNS3int['ENERGY'][ie100:]),HeNS3int[i][ie100:]*convMb,'orange',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(BeNS3int['ENERGY'][ie100:]),BeNS3int[i][ie100:]*convMb,'forestgreen',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(CNS3int['ENERGY'][ie100:]),CNS3int[i][ie100:]*convMb,'dodgerblue',linewidth=1,label='_nolegend_')
    plt.plot(convkeV(ONS3int['ENERGY'][ie100:]),ONS3int[i][ie100:]*convMb,'darkorchid',linewidth=1,label='_nolegend_')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5,position=(1,0))
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.ylabel("Ionization Cross Section (Mb)/Z$^2$", fontsize=28,labelpad=5)
# ax1.legend(loc='lower left',fontsize=26)
ax1.legend(loc='upper left',bbox_to_anchor=(0.175, 1.15, 0, 0),fontsize=26,ncol=6)
plt.text(xtext, ytext, '(a)',fontsize=28)

ax2 = plt.subplot(122)
for i in head_adn[1:]:
    plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int[i][ie100:]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int[i][ie100:]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int[i][ie100:]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int[i][ie100:]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int[i][ie100:]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convkeV(PS2int['ENERGY'][ie100:]),PS2int[i][ie100:]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS2int['ENERGY'][ie100:]),HeS2int[i][ie100:]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS2int['ENERGY'][ie100:]),BeS2int[i][ie100:]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS2int['ENERGY'][ie100:]),CS2int[i][ie100:]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS2int['ENERGY'][ie100:]),OS2int[i][ie100:]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int[i][ie100:]*convMb,'red',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int[i][ie100:]*convMb,'orange',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int[i][ie100:]*convMb,'forestgreen',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int[i][ie100:]*convMb,'dodgerblue',linewidth=1, label='_nolegend_')
    plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int[i][ie100:]*convMb,'darkorchid',linewidth=1, label='_nolegend_')
plt.axvline(2000,linestyle='--',color='tab:gray',linewidth=1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
# plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5)
plt.text(xtext, ytext, '(b)',fontsize=28)
fig.subplots_adjust(hspace=0, wspace=0.125)

plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()

# %% [markdown]
# # Input $\bar{p}$ data, change $\sigma$ units and interpolate

# %%
APS1=pd.read_csv(folder+"AP/AP_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
if APS1['ENERGY'][0]==100: APS1['ENERGY']=np.sqrt(APS1['ENERGY']/25.)

# %%
head_APS1=list(APS1.columns.values)

# %%
for i in head_APS1[1:]:
    APS1[i]=APS1[i]/10.

# %%
APS1int=[]
APS1int=interp_XS(APS1,'ENERGY','URACILO','cubic')
for i in head_APS1[2:]:
    dum1=interp_XS(APS1,'ENERGY',i,'cubic')
    APS1int[i]=dum1[i]

# %% [markdown]
# # Input of experimental data

# %%
folderexp='~/newmonti/experimentos/'

# %%
A_p=pd.read_csv(folderexp+'adenina+p_iriki2011.dat',sep=' ',delimiter='\s+',header='infer')

# %%
A_e=pd.read_csv(folderexp+'adenina+e_mozejko2003.dat',sep=' ',delimiter='\s+',header='infer')

# %%
C_e=pd.read_csv(folderexp+'cytosina+e_mozejko2003.dat',sep=' ',delimiter='\s+',header='infer')

# %%
G_e=pd.read_csv(folderexp+'guanina+e_mozejko2003.dat',sep=' ',delimiter='\s+',header='infer')

# %%
T_e=pd.read_csv(folderexp+'timina+e_mozejko2003.dat',sep=' ',delimiter='\s+',header='infer')

# %%
U_p=pd.read_csv(folderexp+'uracilo+p_itoh2013.dat',sep=' ',delimiter='\s+',header='infer')

# %%
PYR_p=pd.read_csv(folderexp+'pirimidina+p_wolff2014',sep=' ',delimiter='\s+',header='infer')

# %%
bug17=pd.read_csv(folderexp+'e_bug2017.dat',sep=' ',delimiter='\s+',header='infer')

# %%
THF_p=pd.read_csv(folderexp+'THF+p_wang2016.dat',sep=' ',delimiter='\s+',header='infer')

# %%
THF_e09=pd.read_csv(folderexp+'THF+e_fuss2009.dat',sep=' ',delimiter='\s+',header='infer')
THF_e19=pd.read_csv(folderexp+'THF+e_wolff2019.dat',sep=' ',delimiter='\s+',header='infer')

# %%
'uracil+ions_agnihotriRef14-15.dat'

# %%
# Out:
#       Ep(keV)  Ee(ev)  e+THF    e+PY
# 0   551.26792     300   7.99    7.48
# 1   735.02389     400   6.63    6.27
# 2   918.77986     500   5.69    5.41
# 3  1102.53583     600   4.99    4.76
# 4  1286.29180     700   4.45    4.26
# 5  1470.04778     800   4.03  387.00
# 6  1653.80375     900   3.68    3.54
# 7  1837.55972    1000   3.39    3.27

# %%
xmin=60.
xmax=10000
ymin=2.
ymax=200.
xtext=250.
ytext=6.

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(221)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convMb,'red',linewidth=2,label=r'H$^{+}$')
plt.plot(convkeV(APS1int['ENERGY']),APS1int['ADENINA']*convMb*0.8,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLADENINA'][ie100:]*convMb/2**2,'orange',linewidth=2,label=r'He$^{+2}$')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLADENINA'][ie100:]*convMb/4**2,'forestgreen',linewidth=2,label=r'Be$^{+4}$')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLADENINA'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2,label=r'C$^{+6}$')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLADENINA'][ie100:]*convMb/8**2,'darkorchid',linewidth=2,label=r'O$^{+8}$')
# experimentos #
Ap, = ax1.plot(A_p['E'],A_p['CS']/45*100,color='red',marker='o',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
Ae, = ax1.plot(A_e['Ep'][0:5],A_e['CS'][0:5]/45*100,color='tab:gray',marker='s',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='e')
#ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=26,ncol=6)
ax1.legend([Ap,Ae],['p','e'],loc='best',fontsize=26,handletextpad=0.1,labelspacing=0.1,edgecolor=None)
plt.text(xtext, ytext, 'Adenine',fontsize=26)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=26)
plt.text(70, PS1int['SLADENINA'][ie100]*convMb*1.2, r'$+1$',color='red',fontsize=22)
plt.text(70, APS1int['ADENINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLADENINA'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLADENINA'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLADENINA'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLADENINA'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)
plt.ylabel("Ionization Cross Section/Z$^2$ (Mb)", fontsize=28,labelpad=5,position=(1,0.))
plt.tick_params(labelsize=26);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### CITOSINA ###
ax2 = plt.subplot(222)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY']),APS1int['CITOSINA']*convMb*0.95,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLCITOSINA'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLCITOSINA'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLCITOSINA'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLCITOSINA'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][0:5],C_e['CS'][0:5]/37*100,color='tab:gray',marker='s',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='e')
plt.text(xtext, ytext, 'Citosine',fontsize=26)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=26)
plt.text(70, PS1int['SLCITOSINA'][ie100]*convMb*1.2, r'$+1$',color='red',fontsize=22)
plt.text(70, APS1int['ADENINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLCITOSINA'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLCITOSINA'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLCITOSINA'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLCITOSINA'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)
plt.tick_params(labelsize=26);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(223)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY']),APS1int['GUANINA']*convMb*0.73,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLGUANINA'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLGUANINA'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLGUANINA'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLGUANINA'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:5],G_e['CS'][0:5]/49*100,color='tab:gray',marker='s',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='e')
plt.text(xtext, ytext, 'Guanine',fontsize=26)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=26)
plt.text(70, PS1int['SLGUANINA'][ie100]*convMb*1.2, r'$+1$',color='red',fontsize=22)
plt.text(70, APS1int['GUANINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLGUANINA'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLGUANINA'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLGUANINA'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLGUANINA'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)
plt.tick_params(labelsize=26);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### TIMINA ###
ax4 = plt.subplot(224)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
plt.plot(convkeV(APS1int['ENERGY']),APS1int['TIMINA']*convMb*0.86,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLTIMINA'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLTIMINA'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLTIMINA'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLTIMINA'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:5],T_e['CS'][0:5]/42*100,color='tab:gray',marker='s',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='e')
plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5,position=(-0.15,0))
plt.text(xtext, ytext, 'Thymine',fontsize=26)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=26)
plt.text(70, PS1int['SLTIMINA'][ie100]*convMb*1.2, r'$+1$',color='red',fontsize=22)
plt.text(70, APS1int['TIMINA'][0]*convMb*0.85, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLTIMINA'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLTIMINA'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLTIMINA'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLTIMINA'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)
plt.tick_params(labelsize=26);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn1.eps')
plt.show()

# %%
xmin=60.
xmax=10000
ymin=2.
ymax=200.
xtext=250.
ytext=5.

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### URACILO ###
ax1 = plt.subplot(221)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convMb,'red',linewidth=2,label=r'H$^{+}$')
plt.plot(convkeV(APS1int['ENERGY']),APS1int['URACILO']*convMb,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLURACILO'][ie100:]*convMb/2**2,'orange',linewidth=2,label=r'He$^{+2}$')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLURACILO'][ie100:]*convMb/4**2,'forestgreen',linewidth=2,label=r'Be$^{+4}$')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLURACILO'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2,label=r'C$^{+6}$')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLURACILO'][ie100:]*convMb/8**2,'darkorchid',linewidth=2,label=r'O$^{+8}$')
# experiments
Up, = ax1.plot(U_p['E'],U_p['CS']/36*100,color='red',marker='^',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
ax1.legend([Up],['p'],loc='best',fontsize=26,handletextpad=0.1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.text(xtext, ytext, 'Uracil',fontsize=26)
plt.text(70, PS1int['SLURACILO'][ie100]*convMb*1.2, r'$+1$',color='red',fontsize=22)
plt.text(70, APS1int['URACILO'][0]*convMb*0.95, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLURACILO'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLURACILO'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLURACILO'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLURACILO'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)
plt.ylabel("Ionization Cross Section/Z$^2$ (Mb)", fontsize=28,labelpad=5,position=(1,0.))
#ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=26,ncol=6)

### DNA BACKBONE ###
plt.tick_params(labelsize=26);
ax2 = plt.subplot(222)
plt.plot(convkeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
#plt.plot(convkeV(APS1int['ENERGY']),APS1int['']*convMb*0.95,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS1int['ENERGY'][ie100:]),HeS1int['SLBACKBONE'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS1int['ENERGY'][ie100:]),BeS1int['SLBACKBONE'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS1int['ENERGY'][ie100:]),CS1int['SLBACKBONE'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS1int['ENERGY'][ie100:]),OS1int['SLBACKBONE'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.text(xtext, ytext, 'DNA backbone',fontsize=26)
plt.text(70, PS1int['SLBACKBONE'][ie100]*convMb*1.1, r'$+1$',color='red',fontsize=22)
#plt.text(70, APS1int['ADENINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS1int['SLBACKBONE'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS1int['SLBACKBONE'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS1int['SLBACKBONE'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS1int['SLBACKBONE'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)

### PYRIMIDINA ###
ax3 = plt.subplot(223)
plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
#plt.plot(convkeV(APS1int['ENERGY']),APS1int['GUANINA']*convMb*0.73,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H4N2'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H4N2'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H4N2'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H4N2'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
PYRp, = ax3.plot(PYR_p['E'][2:],PYR_p['au'][2:]/28*convMb,color='red',marker='D',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
PYRe, = ax3.plot(bug17['Ep(keV)'],bug17['e+PY']/28*100,color='tab:gray',marker='p',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
ax3.legend([PYRp,PYRe],['p','e'],loc='best',fontsize=26,handletextpad=0.1,labelspacing=0.1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.text(xtext, ytext, 'Pyrimidine',fontsize=26)
plt.text(70, PS3int['SLC4H4N2'][ie100]*convMb*1.1, r'$+1$',color='red',fontsize=22)
#plt.text(70, APS1int['GUANINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS3int['SLC4H4N2'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS3int['SLC4H4N2'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS3int['SLC4H4N2'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS3int['SLC4H4N2'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)

### THF ###
ax4 = plt.subplot(224)
plt.plot(convkeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convMb,'red',linewidth=2, label='_nolegend_')
#plt.plot(convkeV(APS1int['ENERGY']),APS1int['GUANINA']*convMb*0.73,'red',linestyle='--',linewidth=2,label=r'$\bar{p}$')
plt.plot(convkeV(HeS3int['ENERGY'][ie100:]),HeS3int['SLC4H8O1'][ie100:]*convMb/2**2,'orange',linewidth=2, label='_nolegend_')
plt.plot(convkeV(BeS3int['ENERGY'][ie100:]),BeS3int['SLC4H8O1'][ie100:]*convMb/4**2,'forestgreen',linewidth=2, label='_nolegend_')
plt.plot(convkeV(CS3int['ENERGY'][ie100:]),CS3int['SLC4H8O1'][ie100:]*convMb/6**2,'dodgerblue',linewidth=2, label='_nolegend_')
plt.plot(convkeV(OS3int['ENERGY'][ie100:]),OS3int['SLC4H8O1'][ie100:]*convMb/8**2,'darkorchid',linewidth=2, label='_nolegend_')
THFp, = ax4.plot(THF_p['Ep'],THF_p['au']/28*convMb,color='red',marker='v',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
THFe09, = ax4.plot(THF_e09['Ep(kev)'],THF_e09['CS']/28*100,color='tab:gray',marker='*',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
THFe17, = ax4.plot(bug17['Ep(keV)'],bug17['e+THF']/28*100,color='tab:gray',marker='P',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
THFe19, = ax4.plot(convkeV(THF_e19['v(au)']),THF_e19['au']/28*convMb,color='tab:gray',marker='d',markersize=10,markeredgewidth=2,markerfacecolor='none',linestyle=' ',label='p')
ax4.legend([THFp,THFe09,THFe17,THFe19],['p','e','e','e'],loc='upper right',fontsize=26,handletextpad=0.1,labelspacing=0.1)
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Impact Energy (keV/amu)", fontsize=28,labelpad=5,position=(-0.15,0))
plt.text(xtext, ytext, 'THF',fontsize=26)
plt.text(70, PS3int['SLC4H8O1'][ie100]*convMb*1.1, r'$+1$',color='red',fontsize=22)
#plt.text(70, APS1int['GUANINA'][0]*convMb*0.8, r'$-1$',color='red',fontsize=22)
plt.text(70, HeS3int['SLC4H8O1'][ie100]*convMb*0.75/2**2, r'$+2$',color='orange',fontsize=22)
plt.text(70, BeS3int['SLC4H8O1'][ie100]*convMb*0.85/4**2, r'$+4$',color='forestgreen',fontsize=22)
plt.text(70, CS3int['SLC4H8O1'][ie100]*convMb*0.8/6**2, r'$+6$',color='dodgerblue',fontsize=22)
plt.text(70, OS3int['SLC4H8O1'][ie100]*convMb*0.8/8**2, r'$+8$',color='darkorchid',fontsize=22)

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig('../adn2.eps')
plt.show()
