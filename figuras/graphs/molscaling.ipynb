# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder="~/newmonti/calculos/"

# %%
PS1=pd.read_csv(folder+"P_new/P_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS2=pd.read_csv(folder+"P_new/P_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS3=pd.read_csv(folder+"P_new/P_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS1=pd.read_csv(folder+"He2_new/He2_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS2=pd.read_csv(folder+"He2_new/He2_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS3=pd.read_csv(folder+"He2_new/He2_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS1=pd.read_csv(folder+"Be4_new/Be4_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS2=pd.read_csv(folder+"Be4_new/Be4_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS3=pd.read_csv(folder+"Be4_new/Be4_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS1=pd.read_csv(folder+"C6_new/C6_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS2=pd.read_csv(folder+"C6_new/C6_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS3=pd.read_csv(folder+"C6_new/C6_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS1=pd.read_csv(folder+"O8_new/O8_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS2=pd.read_csv(folder+"O8_new/O8_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS3=pd.read_csv(folder+"O8_new/O8_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

# %%
PNS1=pd.read_csv(folder+"P_new/P_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
PNS2=pd.read_csv(folder+"P_new/P_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
PNS3=pd.read_csv(folder+"P_new/P_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
HeNS1=pd.read_csv(folder+"He2_new/He2_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS2=pd.read_csv(folder+"He2_new/He2_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS3=pd.read_csv(folder+"He2_new/He2_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
BeNS1=pd.read_csv(folder+"Be4_new/Be4_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS2=pd.read_csv(folder+"Be4_new/Be4_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS3=pd.read_csv(folder+"Be4_new/Be4_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
CNS1=pd.read_csv(folder+"C6_new/C6_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
CNS2=pd.read_csv(folder+"C6_new/C6_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
CNS3=pd.read_csv(folder+"C6_new/C6_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
ONS1=pd.read_csv(folder+"O8_new/O8_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
ONS2=pd.read_csv(folder+"O8_new/O8_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
ONS3=pd.read_csv(folder+"O8_new/O8_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

# %%
head_adn=list(PS1.columns.values)
head_CHn=list(PS2.columns.values)
head_PYR=list(PS3.columns.values)

# %%
headNS_adn=list(PNS1.columns.values)
headNS_CHn=list(PNS2.columns.values)
headNS_PYR=list(PNS3.columns.values)

# %%
convMb=0.28002*100

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

fig = plt.figure(figsize=(18,9))
ax1 = plt.subplot(121)
pline=plt.plot(PNS1['ENERGY'],PNS1['ADENINA']*convMb,'k',label=r'H$^{+}$')
Heline=plt.plot(HeNS1['ENERGY'],HeNS1['ADENINA']*convMb,'r',label=r'He$^{+2}$')
Beline=plt.plot(BeNS1['ENERGY'],BeNS1['ADENINA']*convMb,'tab:green',label=r'Be$^{+4}$')
Cline=plt.plot(CNS1['ENERGY'],CNS1['ADENINA']*convMb,'tab:blue',label=r'C$^{+6}$')
Oline=plt.plot(ONS1['ENERGY'],ONS1['ADENINA']*convMb,'tab:orange',label=r'O$^{+8}$')
for i in headNS_adn:
    plt.plot(PNS1['ENERGY'],PNS1[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeNS1['ENERGY'],HeNS1[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeNS1['ENERGY'],BeNS1[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CNS1['ENERGY'],CNS1[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(ONS1['ENERGY'],ONS1[i]*convMb,'tab:orange', label='_nolegend_')
for i in headNS_CHn:
    plt.plot(PNS2['ENERGY'],PNS2[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeNS2['ENERGY'],HeNS2[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeNS2['ENERGY'],BeNS2[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CNS2['ENERGY'],CNS2[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(ONS2['ENERGY'],ONS2[i]*convMb,'tab:orange', label='_nolegend_')
for i in headNS_PYR:
    plt.plot(PNS3['ENERGY'],PNS3[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeNS3['ENERGY'],HeNS3[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeNS3['ENERGY'],BeNS3[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CNS3['ENERGY'],CNS3[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(ONS3['ENERGY'],ONS3[i]*convMb,'tab:orange', label='_nolegend_')
plt.xlim(100,10000)
plt.ylim(0.5,2000)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Energy (keV)", fontsize=28)
plt.ylabel("Cross Section (Mb)", fontsize=28,labelpad=5)
ax1.legend(loc='lower left',fontsize=26)
plt.text(6000, 1000, '(a)',fontsize=28)

ax2 = plt.subplot(122)
pline=plt.plot(PS1['ENERGY'],PS1['SLADENINA']*convMb,'k',label=r'H$^{+}$')
Heline=plt.plot(HeS1['ENERGY'],HeS1['SLADENINA']*convMb,'r',label=r'He$^{+2}$')
Beline=plt.plot(BeS1['ENERGY'],BeS1['SLADENINA']*convMb,'tab:green',label=r'Be$^{+4}$')
Cline=plt.plot(CS1['ENERGY'],CS1['SLADENINA']*convMb,'tab:blue',label=r'C$^{+6}$')
Oline=plt.plot(OS1['ENERGY'],OS1['SLADENINA']*convMb,'tab:orange',label=r'O$^{+8}$')
for i in head_adn:
    plt.plot(PS1['ENERGY'],PS1[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeS1['ENERGY'],HeS1[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeS1['ENERGY'],BeS1[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CS1['ENERGY'],CS1[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(OS1['ENERGY'],OS1[i]*convMb,'tab:orange', label='_nolegend_')
for i in head_CHn:
    plt.plot(PS2['ENERGY'],PS2[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeS2['ENERGY'],HeS2[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeS2['ENERGY'],BeS2[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CS2['ENERGY'],CS2[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(OS2['ENERGY'],OS2[i]*convMb,'tab:orange', label='_nolegend_')
for i in head_PYR:
    plt.plot(PS3['ENERGY'],PS3[i]*convMb,'k', label='_nolegend_')
    plt.plot(HeS3['ENERGY'],HeS3[i]*convMb,'r', label='_nolegend_')
    plt.plot(BeS3['ENERGY'],BeS3[i]*convMb,'tab:green', label='_nolegend_')
    plt.plot(CS3['ENERGY'],CS3[i]*convMb,'tab:blue', label='_nolegend_')
    plt.plot(OS3['ENERGY'],OS3[i]*convMb,'tab:orange', label='_nolegend_')
plt.axvline(2000,linestyle='--',color='tab:gray')
plt.xlim(100,10000)
plt.ylim(0.5,2000)
plt.yscale('log')
plt.xscale('log')
plt.tick_params(labelsize=26);
plt.xlabel("Energy (keV)", fontsize=28)
ax2.legend(loc='lower left',fontsize=26)
plt.text(6000, 1000, '(b)',fontsize=28)
fig.subplots_adjust(hspace=0, wspace=0.125)

plt.savefig("../molscaling85.eps",bbox_inches='tight')
plt.show()
