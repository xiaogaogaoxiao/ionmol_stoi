# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
convMb=0.28002*100

def convkeV(x):
    return 25.0*(x**2)

convcm2=0.28002

def convMeV(x):
    return 25.0*(x**2)/1000.

# %%
folder="~/ionmol_stoi/calculos/"

PS1=pd.read_csv(folder+"P/P_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS2=pd.read_csv(folder+"P/P_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
PS3=pd.read_csv(folder+"P/P_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS1=pd.read_csv(folder+"He2/He2_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS2=pd.read_csv(folder+"He2/He2_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
HeS3=pd.read_csv(folder+"He2/He2_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS1=pd.read_csv(folder+"Be4/Be4_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
BeS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS1=pd.read_csv(folder+"C6/C6_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS2=pd.read_csv(folder+"C6/C6_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
CS3=pd.read_csv(folder+"C6/C6_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS1=pd.read_csv(folder+"O8/O8_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS2=pd.read_csv(folder+"O8/O8_CDW_CHn_NV.dat",sep=' ',delimiter='\s+',header='infer')
OS3=pd.read_csv(folder+"O8/O8_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

PNS1=pd.read_csv(folder+"P/P_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
PNS2=pd.read_csv(folder+"P/P_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
PNS3=pd.read_csv(folder+"P/P_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
HeNS1=pd.read_csv(folder+"He2/He2_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS2=pd.read_csv(folder+"He2/He2_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
HeNS3=pd.read_csv(folder+"He2/He2_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
BeNS1=pd.read_csv(folder+"Be4/Be4_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS2=pd.read_csv(folder+"Be4/Be4_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
BeNS3=pd.read_csv(folder+"Be4/Be4_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
CNS1=pd.read_csv(folder+"C6/C6_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
CNS2=pd.read_csv(folder+"C6/C6_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
CNS3=pd.read_csv(folder+"C6/C6_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')
ONS1=pd.read_csv(folder+"O8/O8_CDW_adn.dat",sep=' ',delimiter='\s+',header='infer')
ONS2=pd.read_csv(folder+"O8/O8_CDW_CHn.dat",sep=' ',delimiter='\s+',header='infer')
ONS3=pd.read_csv(folder+"O8/O8_CDW_PYR.dat",sep=' ',delimiter='\s+',header='infer')

head_adn=list(PS1.columns.values)
head_CHn=list(PS2.columns.values)
head_PYR=list(PS3.columns.values)

headNS_adn=list(PNS1.columns.values)
headNS_CHn=list(PNS2.columns.values)
headNS_PYR=list(PNS3.columns.values)

# %% [markdown]
# # Convert energy from keV to a.u.

# %%
PS1['ENERGY']=np.sqrt(PS1['ENERGY']/25.)
PS2['ENERGY']=np.sqrt(PS2['ENERGY']/25.)
PS3['ENERGY']=np.sqrt(PS3['ENERGY']/25.)
HeS1['ENERGY']=np.sqrt(HeS1['ENERGY']/25.)
HeS2['ENERGY']=np.sqrt(HeS2['ENERGY']/25.)
HeS3['ENERGY']=np.sqrt(HeS3['ENERGY']/25.)
BeS1['ENERGY']=np.sqrt(BeS1['ENERGY']/25.)
BeS2['ENERGY']=np.sqrt(BeS2['ENERGY']/25.)
BeS3['ENERGY']=np.sqrt(BeS3['ENERGY']/25.)
CS1['ENERGY']=np.sqrt(CS1['ENERGY']/25.)
CS2['ENERGY']=np.sqrt(CS2['ENERGY']/25.)
CS3['ENERGY']=np.sqrt(CS3['ENERGY']/25.)
OS1['ENERGY']=np.sqrt(OS1['ENERGY']/25.)
OS2['ENERGY']=np.sqrt(OS2['ENERGY']/25.)
OS3['ENERGY']=np.sqrt(OS3['ENERGY']/25.)

PNS1['ENERGY']=np.sqrt(PNS1['ENERGY']/25.)
PNS2['ENERGY']=np.sqrt(PNS2['ENERGY']/25.)
PNS3['ENERGY']=np.sqrt(PNS3['ENERGY']/25.)
HeNS1['ENERGY']=np.sqrt(HeNS1['ENERGY']/25.)
HeNS2['ENERGY']=np.sqrt(HeNS2['ENERGY']/25.)
HeNS3['ENERGY']=np.sqrt(HeNS3['ENERGY']/25.)
BeNS1['ENERGY']=np.sqrt(BeNS1['ENERGY']/25.)
BeNS2['ENERGY']=np.sqrt(BeNS2['ENERGY']/25.)
BeNS3['ENERGY']=np.sqrt(BeNS3['ENERGY']/25.)
CNS1['ENERGY']=np.sqrt(CNS1['ENERGY']/25.)
CNS2['ENERGY']=np.sqrt(CNS2['ENERGY']/25.)
CNS3['ENERGY']=np.sqrt(CNS3['ENERGY']/25.)
ONS1['ENERGY']=np.sqrt(ONS1['ENERGY']/25.)
ONS2['ENERGY']=np.sqrt(ONS2['ENERGY']/25.)
ONS3['ENERGY']=np.sqrt(ONS3['ENERGY']/25.)

# %% [markdown]
# # Make cubic spline interpolation on data

# %%
from scipy import interpolate

def interp_XS(XY,ix,iy,kind):
    x=XY[ix].values
    y=XY[iy].values
    n=len(x)
    spline = interpolate.interp1d(x, y, kind=kind)
    xnew = np.arange(x[0], x[n-1], 0.1)
    ynew = spline(xnew)
    XYnew = pd.DataFrame({ix:xnew, iy:ynew})
    return XYnew

# %%
PS1int=[]
PNS1int=[]
PS1int=interp_XS(PS1,'ENERGY','SLURACILO','cubic')
PNS1int=interp_XS(PNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(PS1,'ENERGY',i,'cubic')
    PS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(PNS1,'ENERGY',i,'cubic')
    PNS1int[i]=dumn1[i]

PS2int=[]
PNS2int=[]
PS2int=interp_XS(PS2,'ENERGY','SLCH4','cubic')
PNS2int=interp_XS(PNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(PS2,'ENERGY',i,'cubic')
    PS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(PNS2,'ENERGY',i,'cubic')
    PNS2int[i]=dumn2[i]

PS3int=[]
PNS3int=[]
PS3int=interp_XS(PS3,'ENERGY','SLC4H4N2','cubic')
PNS3int=interp_XS(PNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(PS3,'ENERGY',i,'cubic')
    PS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(PNS3,'ENERGY',i,'cubic')
    PNS3int[i]=dumn3[i]

HeS1int=[]
HeNS1int=[]
HeS1int=interp_XS(HeS1,'ENERGY','SLURACILO','cubic')
HeNS1int=interp_XS(HeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(HeS1,'ENERGY',i,'cubic')
    HeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(HeNS1,'ENERGY',i,'cubic')
    HeNS1int[i]=dumn1[i]

HeS2int=[]
HeNS2int=[]
HeS2int=interp_XS(HeS2,'ENERGY','SLCH4','cubic')
HeNS2int=interp_XS(HeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(HeS2,'ENERGY',i,'cubic')
    HeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(HeNS2,'ENERGY',i,'cubic')
    HeNS2int[i]=dumn2[i]

HeS3int=[]
HeNS3int=[]
HeS3int=interp_XS(HeS3,'ENERGY','SLC4H4N2','cubic')
HeNS3int=interp_XS(HeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(HeS3,'ENERGY',i,'cubic')
    HeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(HeNS3,'ENERGY',i,'cubic')
    HeNS3int[i]=dumn3[i]

BeS1int=[]
BeNS1int=[]
BeS1int=interp_XS(BeS1,'ENERGY','SLURACILO','cubic')
BeNS1int=interp_XS(BeNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(BeS1,'ENERGY',i,'cubic')
    BeS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(BeNS1,'ENERGY',i,'cubic')
    BeNS1int[i]=dumn1[i]

BeS2int=[]
BeNS2int=[]
BeS2int=interp_XS(BeS2,'ENERGY','SLCH4','cubic')
BeNS2int=interp_XS(BeNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(BeS2,'ENERGY',i,'cubic')
    BeS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(BeNS2,'ENERGY',i,'cubic')
    BeNS2int[i]=dumn2[i]

BeS3int=[]
BeNS3int=[]
BeS3int=interp_XS(BeS3,'ENERGY','SLC4H4N2','cubic')
BeNS3int=interp_XS(BeNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(BeS3,'ENERGY',i,'cubic')
    BeS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(BeNS3,'ENERGY',i,'cubic')
    BeNS3int[i]=dumn3[i]

CS1int=[]
CNS1int=[]
CS1int=interp_XS(CS1,'ENERGY','SLURACILO','cubic')
CNS1int=interp_XS(CNS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(CS1,'ENERGY',i,'cubic')
    CS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(CNS1,'ENERGY',i,'cubic')
    CNS1int[i]=dumn1[i]

CS2int=[]
CNS2int=[]
CS2int=interp_XS(CS2,'ENERGY','SLCH4','cubic')
CNS2int=interp_XS(CNS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(CS2,'ENERGY',i,'cubic')
    CS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(CNS2,'ENERGY',i,'cubic')
    CNS2int[i]=dumn2[i]

CS3int=[]
CNS3int=[]
CS3int=interp_XS(CS3,'ENERGY','SLC4H4N2','cubic')
CNS3int=interp_XS(CNS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(CS3,'ENERGY',i,'cubic')
    CS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(CNS3,'ENERGY',i,'cubic')
    CNS3int[i]=dumn3[i]

OS1int=[]
ONS1int=[]
OS1int=interp_XS(OS1,'ENERGY','SLURACILO','cubic')
ONS1int=interp_XS(ONS1,'ENERGY','URACILO','cubic')
for i in head_adn[2:]:
    dum1=interp_XS(OS1,'ENERGY',i,'cubic')
    OS1int[i]=dum1[i]
for i in headNS_adn[2:]:
    dumn1=interp_XS(ONS1,'ENERGY',i,'cubic')
    ONS1int[i]=dumn1[i]

OS2int=[]
ONS2int=[]
OS2int=interp_XS(OS2,'ENERGY','SLCH4','cubic')
ONS2int=interp_XS(ONS2,'ENERGY','CH4','cubic')
for i in head_CHn[2:]:
    dum2=interp_XS(OS2,'ENERGY',i,'cubic')
    OS2int[i]=dum2[i]
for i in headNS_CHn[2:]:
    dumn2=interp_XS(ONS2,'ENERGY',i,'cubic')
    ONS2int[i]=dumn2[i]

OS3int=[]
ONS3int=[]
OS3int=interp_XS(OS3,'ENERGY','SLC4H4N2','cubic')
ONS3int=interp_XS(ONS3,'ENERGY','C4H4N2','cubic')
for i in head_PYR[2:]:
    dum3=interp_XS(OS3,'ENERGY',i,'cubic')
    OS3int[i]=dum3[i]
for i in headNS_PYR[2:]:
    dumn3=interp_XS(ONS3,'ENERGY',i,'cubic')
    ONS3int[i]=dumn3[i]

# %%
co_p='tab:red'
co_ap='tab:red'
co_he='tab:green'
co_be='tab:blue'
co_c='tab:purple'
co_o='tab:orange'

# %% [markdown]
# # Input $\bar{p}$ data, change $\sigma$ units and interpolate

# %%
APS1=pd.read_csv(folder+"AP/AP_CDW_adn_NV.dat",sep=' ',delimiter='\s+',header='infer')
APS3=pd.read_csv(folder+"AP/AP_CDW_PYR_NV.dat",sep=' ',delimiter='\s+',header='infer')

if APS1['ENERGY'][0]==25: 
    APS1['ENERGY']=np.sqrt(APS1['ENERGY']/25.)
if APS3['ENERGY'][0]==25: 
    APS3['ENERGY']=np.sqrt(APS3['ENERGY']/25.)
    
head_APS1=list(APS1.columns.values)
head_APS3=list(APS3.columns.values)

APS1int=[]
APS1int=interp_XS(APS1,'ENERGY','SLURACILO','cubic')
for i in head_APS1[2:]:
    dum1=interp_XS(APS1,'ENERGY',i,'cubic')
    APS1int[i]=dum1[i]

APS3int=[]
APS3int=interp_XS(APS3,'ENERGY','SLC4H4N2','cubic')
for i in head_APS3[2:]:
    dum1=interp_XS(APS3,'ENERGY',i,'cubic')
    APS3int[i]=dum1[i]

# %% [markdown]
# # Input of experimental data

# %%
folderexp='~/ionmol_stoi/experimentos/'

A_p=pd.read_csv(folderexp+'adenina+p_iriki2011.dat',sep=' ',delimiter='\s+',header='infer')
A_e=pd.read_csv(folderexp+'adenine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
C_e=pd.read_csv(folderexp+'cytosine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
G_e=pd.read_csv(folderexp+'guanine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
T_e=pd.read_csv(folderexp+'thymine+e_rahman2016.dat',sep=' ',delimiter='\s+',header='infer')
U_p=pd.read_csv(folderexp+'uracilo+p_itoh2013.dat',sep=' ',delimiter='\s+',header='infer')
PYR_p=pd.read_csv(folderexp+'pirimidina+p_wolff2014',sep=' ',delimiter='\s+',header='infer')
bug17=pd.read_csv(folderexp+'e_bug2017.dat',sep=' ',delimiter='\s+',header='infer')
THF_p=pd.read_csv(folderexp+'THF+p_wang2016.dat',sep=' ',delimiter='\s+',header='infer')
THF_e09=pd.read_csv(folderexp+'THF+e_fuss2009.dat',sep=' ',delimiter='\s+',header='infer')
THF_e19=pd.read_csv(folderexp+'THF+e_wolff2019.dat',sep=' ',delimiter='\s+',header='infer')
U_c4=pd.read_csv(folderexp+'uracil+c4_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_c6=pd.read_csv(folderexp+'uracil+c6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_f6=pd.read_csv(folderexp+'uracil+f6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_o6=pd.read_csv(folderexp+'uracil+o6_ref14-15.dat',sep=' ',delimiter='\s+',header=None)
U_of8=pd.read_csv(folderexp+'uracil+o8f8_ref14-15.dat',sep=' ',delimiter='\s+',header=None)

A_e['Ep']=A_e['Ee']*1.8375597
C_e['Ep']=C_e['Ee']*1.8375597
G_e['Ep']=G_e['Ee']*1.8375597

iAe=len(A_e[A_e['Ep']>500])
iCe=len(C_e[C_e['Ep']<500])
iGe=len(G_e[G_e['Ep']>500])
iTe=len(T_e[T_e['Ep']>500])
iTHFe19=len(THF_e19[THF_e19['Ep']>500])

# %%
dum=PS1int[convkeV(PS1int['ENERGY']) < 100.]
ie100=len(dum)

# %%
itickssize=28
imolsize=30
ilabelsize=30
ilegsize=26

# %% [markdown]
# # Ionization cross section in terms of $n_e$

# %%
cross_ne=pd.read_csv("data_recta.dat",sep=' ',delimiter='\s+',header='infer',skiprows=(1,2,3))
expH_ne=pd.read_csv("expH_recta.dat",sep=' ',delimiter='\s+',header='infer')
expe_ne=pd.read_csv("expe_recta.dat",sep=' ',delimiter='\s+',header='infer')

# %% [markdown]
# # New scaling:
#
# ## $\bullet$ $\sigma/Z$ and $E/Z$

# %%
iwidth=2.5
xmin=0.005
xmax=15
ymin=0.02
ymax=4.
xtext=0.03
ytext=0.10
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLADENINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLADENINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLADENINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLADENINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experimentos #
Ae, = ax1.plot(A_e['Ep'][0:iAe]/1000.,A_e['CS'][0:iAe]/45,color='dimgray',
               marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=6,
               linestyle=' ',label='_nolegend_')
Ap, = ax1.plot(A_p['E']/1000.,A_p['CS']/45,color=co_p,marker='o',
               markersize=14,markeredgewidth=1.5,markerfacecolor='white',
               linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=10,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### CITOSINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convcm2*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLCITOSINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLCITOSINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLCITOSINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLCITOSINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][iCe:]/1000,C_e['CS'][iCe:]/37,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLGUANINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLGUANINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLGUANINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLGUANINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:iGe]/1000,G_e['CS'][0:iGe]/49,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### TIMINA ###
ax4 = plt.subplot(224)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convcm2*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLTIMINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLTIMINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLTIMINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLTIMINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:iTe]/1000,T_e['CS'][0:iTe]/42,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=5,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.0, wspace=0.0)

plt.savefig('../zscale_adn1.eps',bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=0.005
xmax=15
ymin=0.02
ymax=4.
xtext=0.03
ytext=0.10
icharge=0.07

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### URACILO ###
ax1 = plt.subplot(221)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convcm2*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLURACILO'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLURACILO'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLURACILO'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLURACILO'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experiments
Up, = ax1.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,
               marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc4, = ax1.plot(U_c4[1]/1000/4,U_c4[3]/36*4,color=co_be,
                marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc6, = ax1.plot(U_c6[1]/1000/6,U_c6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uo6, = ax1.plot(U_o6[1]/1000/6,U_o6[3]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uf6, = ax1.plot(U_f6[1]/1000/6,U_f6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uof8, = ax1.plot(U_of8[0]/1000/8,U_of8[1]/36*8,color=co_o,
                 marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize-5,ncol=6)
ax1.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],
           loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### PYRIMIDINA ###
ax2 = plt.subplot(222)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convcm2*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H4N2'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H4N2'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H4N2'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H4N2'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
PYRe, = ax2.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',
                 marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
PYRp, = ax2.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,
                 marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax2.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax3 = plt.subplot(223)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convcm2*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H8O1'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H8O1'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H8O1'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H8O1'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
THFe09, = ax3.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',
                   marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe17, = ax3.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',
                   marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe19, = ax3.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',
                   marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFp, = ax3.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,
                 marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax3.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### DNA BACKBONE ###
ax4 = plt.subplot(224)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convcm2*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLBACKBONE'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLBACKBONE'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLBACKBONE'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLBACKBONE'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')

plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=15,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.0, wspace=0.0)

plt.savefig('../zscale_adn2.eps',bbox_inches='tight')
plt.show()

# %%
iwidth=2.5
xmin=0.005
xmax=15
ymin=0.02
ymax=4.
xtext=0.03
ytext=0.10
icharge=0.07

fig = plt.figure(figsize=(18,18))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(421)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)
plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLADENINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLADENINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLADENINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLADENINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experimentos #
Ae, = ax1.plot(A_e['Ep'][0:iAe]/1000.,A_e['CS'][0:iAe]/45,color='dimgray',
               marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=6,
               linestyle=' ',label='_nolegend_')
Ap, = ax1.plot(A_p['E']/1000.,A_p['CS']/45,color=co_p,marker='o',
               markersize=14,markeredgewidth=1.5,markerfacecolor='white',
               linestyle=' ',label='_nolegend_')

legend1=ax1.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
# plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=10,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### CITOSINA ###
ax2 = plt.subplot(422)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convcm2*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLCITOSINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLCITOSINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLCITOSINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLCITOSINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(C_e['Ep'][iCe:]/1000,C_e['CS'][iCe:]/37,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(423)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLGUANINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLGUANINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLGUANINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLGUANINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(G_e['Ep'][0:iGe]/1000,G_e['CS'][0:iGe]/49,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### TIMINA ###
ax4 = plt.subplot(424)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convcm2*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLTIMINA'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLTIMINA'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLTIMINA'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLTIMINA'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experimentos #
plt.plot(T_e['Ep'][0:iTe]/1000,T_e['CS'][0:iTe]/42,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

# plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=15,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### URACILO ###
ax5 = plt.subplot(425)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convcm2*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLURACILO'][ie100:]*convcm2/2,co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLURACILO'][ie100:]*convcm2/4,co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLURACILO'][ie100:]*convcm2/6,co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLURACILO'][ie100:]*convcm2/8,co_o,linewidth=iwidth,label=r'O$^{+8}$')
# experiments
Up, = ax5.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,
               marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc4, = ax5.plot(U_c4[1]/1000/4,U_c4[3]/36*4,color=co_be,
                marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc6, = ax5.plot(U_c6[1]/1000/6,U_c6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uo6, = ax5.plot(U_o6[1]/1000/6,U_o6[3]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uf6, = ax5.plot(U_f6[1]/1000/6,U_f6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uof8, = ax5.plot(U_of8[0]/1000/8,U_of8[1]/36*8,color=co_o,
                 marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')

legend1=ax5.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize-5,ncol=6)
ax5.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],
           loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15,position=(1,1))
ax5.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax5.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax5.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### PYRIMIDINA ###
ax6 = plt.subplot(426)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convcm2*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H4N2'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H4N2'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H4N2'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H4N2'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
PYRe, = ax6.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',
                 marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
PYRp, = ax6.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,
                 marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax6.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax6.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax6.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax7 = plt.subplot(427)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convcm2*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2,HeS3int['SLC4H8O1'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4,BeS3int['SLC4H8O1'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6,CS3int['SLC4H8O1'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8,OS3int['SLC4H8O1'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')
# experiments
THFe09, = ax7.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',
                   marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe17, = ax7.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',
                   marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe19, = ax7.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',
                   marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFp, = ax7.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,
                 marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax7.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax7.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax7.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax7.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax7.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### DNA BACKBONE ###
ax8 = plt.subplot(428)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
# plt.text(0.008, 1.00, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.013, 1.50, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.023, 1.85, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.042, 1.75, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.075, 1.5, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convcm2*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2,HeS1int['SLBACKBONE'][ie100:]*convcm2/2,co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4,BeS1int['SLBACKBONE'][ie100:]*convcm2/4,co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6,CS1int['SLBACKBONE'][ie100:]*convcm2/6,co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8,OS1int['SLBACKBONE'][ie100:]*convcm2/8,co_o,linewidth=iwidth, label='_nolegend_')

plt.xlabel("Impact Energy/Z (MeV/amu)", fontsize=ilabelsize,labelpad=15,position=(0,0))
ax8.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax8.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax8.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.0, wspace=0.0)

plt.savefig('../zscale.eps',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## $\bullet$ $\sigma/Z^{4/3}$ and $E/Z^{2/3}$

# %%
iwidth=2.5
xmin=0.0101
xmax=15
ymin=0.02
ymax=3.
xtext=0.03
ytext=0.10
icharge=0.07

fig = plt.figure(figsize=(18,18))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

### ADENINA ###
ax1 = plt.subplot(421)
plt.text(xtext, ytext, 'Adenine',fontsize=imolsize)
plt.text(xtext*1.05, ytext*0.55, r'C$_5$H$_5$N$_5$',fontsize=imolsize)
plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLADENINA'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth,label=r'O$^{+8}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLADENINA'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLADENINA'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLADENINA'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLADENINA'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLADENINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experimentos #
Ae, = ax1.plot(A_e['Ep'][0:iAe]/1000.,A_e['CS'][0:iAe]/45,color='dimgray',
               marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=6,
               linestyle=' ',label='_nolegend_')
Ap, = ax1.plot(A_p['E']/1000.,A_p['CS']/45,color=co_p,marker='o',
               markersize=14,markeredgewidth=1.5,markerfacecolor='white',
               linestyle=' ',label='_nolegend_')

handles, labels = ax1.get_legend_handles_labels()
legend1=ax1.legend(handles[::-1], labels[::-1],loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize,ncol=6)
ax1.legend([Ap,Ae],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
# plt.ylabel("Ionization Cross Section/Z ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=10,position=(1,0.))
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
plt.gca().add_artist(legend1)
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### CITOSINA ###
ax2 = plt.subplot(422)
plt.text(xtext, ytext, 'Citosine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_4$H$_5$N$_3$O',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLCITOSINA'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLCITOSINA'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLCITOSINA'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLCITOSINA'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLCITOSINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLCITOSINA'][ie100:]*convcm2*0.7,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experimentos #
plt.plot(C_e['Ep'][iCe:]/1000,C_e['CS'][iCe:]/37,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax2.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax2.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### GUANINA ###
ax3 = plt.subplot(423)
plt.text(xtext, ytext, 'Guanine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_5$N$_5$O',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLGUANINA'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLGUANINA'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLGUANINA'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLGUANINA'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLGUANINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLGUANINA'][ie100:]*convcm2*0.75,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experimentos #
plt.plot(G_e['Ep'][0:iGe]/1000,G_e['CS'][0:iGe]/49,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

ax3.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax3.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax3.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax3.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### TIMINA ###
ax4 = plt.subplot(424)
plt.text(xtext, ytext, 'Thymine',fontsize=imolsize)
plt.text(xtext*0.95, ytext*0.55, r'C$_5$H$_6$N$_2$O$_2$',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLTIMINA'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLTIMINA'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLTIMINA'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLTIMINA'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLTIMINA'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLTIMINA'][ie100:]*convcm2*0.69,co_ap,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experimentos #
plt.plot(T_e['Ep'][0:iTe]/1000,T_e['CS'][0:iTe]/42,color='dimgray',
         marker='s',markersize=14,markeredgewidth=1.5,markerfacecolor='white',markevery=4,
         linestyle=' ',label='e')

plt.xlabel(r"Impact Energy/$Z^{2/3}$ (MeV/amu)", fontsize=ilabelsize,labelpad=15,position=(-0.15,0))
ax4.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax4.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax4.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### URACILO ###
ax5 = plt.subplot(425)
plt.text(xtext, ytext, 'Uracil',fontsize=imolsize)
plt.text(xtext*0.8, ytext*0.55, r'C$_4$H$_4$N$_2$O$_2$',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLURACILO'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth,label=r'O$^{+8}$')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLURACILO'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth,label=r'C$^{+6}$')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLURACILO'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth,label=r'Be$^{+4}$')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLURACILO'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth,label=r'He$^{+2}$')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLURACILO'][ie100:]*convcm2,co_p,linewidth=iwidth,label=r'H$^{+}$')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLURACILO'][ie100:]*convcm2*0.73,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experiments
Up, = ax5.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,
               marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc4, = ax5.plot(U_c4[1]/1000/4,U_c4[3]/36*4,color=co_be,
                marker=r'$\ominus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uc6, = ax5.plot(U_c6[1]/1000/6,U_c6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uo6, = ax5.plot(U_o6[1]/1000/6,U_o6[3]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uf6, = ax5.plot(U_f6[1]/1000/6,U_f6[2]/36*6,color=co_c,
                marker=r'$\oplus$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')
Uof8, = ax5.plot(U_of8[0]/1000/8,U_of8[1]/36*8,color=co_o,
                 marker=r'$\otimes$',markersize=14,markeredgewidth=1,markerfacecolor='white',linestyle=' ',label='_nolegend_')

legend1=ax5.legend(loc='upper left',bbox_to_anchor=(0.03, 1.32, 0, 0),fontsize=ilegsize-5,ncol=6)
ax5.legend([Up,Uc4,Uc6,Uof8],['H$^{+}$','C$^{4+}$','C$^{6+}$, O$^{6+}$, F$^{6+}$','O$^{8+}$, F$^{8+}$'],
           loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
plt.ylabel(r"Ionization Cross Section/$Z^{4/3}$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15,position=(1,1))
ax5.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax5.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax5.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### PYRIMIDINA ###
ax6 = plt.subplot(426)
plt.text(xtext, ytext, 'Pyrimidine',fontsize=imolsize)
plt.text(xtext*1.15, ytext*0.55, r'C$_4$H$_4$N$_2$',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8**(2./3.),OS3int['SLC4H4N2'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6**(2./3.),CS3int['SLC4H4N2'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4**(2./3.),BeS3int['SLC4H4N2'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2**(2./3.),HeS3int['SLC4H4N2'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H4N2'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H4N2'][ie100:]*convcm2*0.69,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experiments
PYRe, = ax6.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',
                 marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
PYRp, = ax6.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,
                 marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax6.legend([PYRp,PYRe],['H$^{+}$','e$^{-}$'],loc='best',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax6.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax6.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')

### THF ###
ax7 = plt.subplot(427)
plt.text(xtext, ytext, 'THF',fontsize=imolsize)
plt.text(xtext*0.9, ytext*0.55, r'C$_4$H$_8$O',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8**(2./3.),OS3int['SLC4H8O1'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6**(2./3.),CS3int['SLC4H8O1'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4**(2./3.),BeS3int['SLC4H8O1'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2**(2./3.),HeS3int['SLC4H8O1'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int['SLC4H8O1'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS3int['ENERGY'][ie100:]),APS3int['SLC4H8O1'][ie100:]*convcm2*0.53,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')
# experiments
THFe09, = ax7.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',
                   marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe17, = ax7.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',
                   marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFe19, = ax7.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',
                   marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')
THFp, = ax7.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,
                 marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='white',linestyle=' ',label='p')

ax7.legend([THFp,THFe09,THFe17,THFe19],['p','e$^{-}$','e$^{-}$','e$^{-}$'],loc='upper right',fontsize=22,handletextpad=0.01,labelspacing=0.1,frameon=False)
ax7.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax7.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax7.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax7.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

### DNA BACKBONE ###
ax8 = plt.subplot(428)
plt.text(xtext*0.9, ytext, 'DNA backbone',fontsize=imolsize)
plt.text(xtext*1.2, ytext*0.55, r'C$_5$HO$_5$P',fontsize=imolsize)
# plt.text(0.016, 0.37, r'$+8$',color=co_o,fontsize=22)
# plt.text(0.022, 0.62, r'$+6$',color=co_c,fontsize=22)
# plt.text(0.035, 0.95, r'$+4$',color=co_be,fontsize=22)
# plt.text(0.060, 1.2, r'$+2$',color=co_he,fontsize=22)
# plt.text(0.1, 1.1, r'$+1$',color=co_p,fontsize=22)
# plt.text(0.125, 1.2, r'$-1$',color=co_ap,fontsize=22)

plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2./3.),OS1int['SLBACKBONE'][ie100:]*convcm2/8**(4./3.),co_o,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLBACKBONE'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2./3.),CS1int['SLBACKBONE'][ie100:]*convcm2/6**(4./3.),co_c,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2./3.),BeS1int['SLBACKBONE'][ie100:]*convcm2/4**(4./3.),co_be,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2./3.),HeS1int['SLBACKBONE'][ie100:]*convcm2/2**(4./3.),co_he,linewidth=iwidth, label='_nolegend_')
plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int['SLBACKBONE'][ie100:]*convcm2,co_p,linewidth=iwidth, label='_nolegend_')
# plt.plot(convMeV(APS1int['ENERGY'][ie100:]),APS1int['SLBACKBONE'][ie100:]*convcm2*0.63,co_p,linestyle='--',linewidth=iwidth,label=r'$\bar{p}$')

plt.xlabel(r"Impact Energy/$Z^{2/3}$ (MeV/amu)", fontsize=ilabelsize,labelpad=10,position=(0,0))
ax8.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax8.tick_params(direction='in',which='minor',length=5,bottom=True, top=True, left=True, right=True);

plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax8.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

for ax in fig.get_axes():
    ax.label_outer()
fig.subplots_adjust(hspace=0.0, wspace=0.0)

plt.savefig('../DBzscale.eps',bbox_inches='tight')
plt.show()

# %%
for i in head_adn[1:]:
    print(i)
# Out:
# SLURACILO
# SLADENINA
# SLTIMINA
# SLCITOSINA
# SLGUANINA
# SLBACKBONE
# SLDRYDNA

# %%
alpha=1.2

# %% [markdown]
# # Universal curve

# %%
ymin=0.02
ymax=20
xmin=convMeV(1.5)
xmax=convMeV(20.)
xtext=5
ytext=10
icharge=65/1000
Zch=np.array([1,2,4,6,8])

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(111)
# plt.text(0.13, 0.05, 'Present work',fontsize=imolsize)

for i in head_adn[1:]:
    plt.plot(convMeV(PS1int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS1int[i][ie100:]*convcm2/Zch[0]**alpha,
             co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS1int[i][ie100:]*convcm2/Zch[1]**alpha,
             co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS1int[i][ie100:]*convcm2/Zch[2]**alpha,
             co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS1int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS1int[i][ie100:]*convcm2/Zch[3]**alpha,
             co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS1int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS1int[i][ie100:]*convcm2/Zch[4]**alpha,
             co_o,linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convMeV(PS2int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS2int[i][ie100:]*convcm2/Zch[0]**alpha,
             co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS2int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS2int[i][ie100:]*convcm2/Zch[1]**alpha,
             co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS2int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS2int[i][ie100:]*convcm2/Zch[2]**alpha,
             co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS2int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS2int[i][ie100:]*convcm2/Zch[3]**alpha,
             co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS2int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS2int[i][ie100:]*convcm2/Zch[4]**alpha,
             co_o,linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convMeV(PS3int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS3int[i][ie100:]*convcm2/Zch[0]**alpha,
             co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS3int[i][ie100:]*convcm2/Zch[1]**alpha,
             co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS3int[i][ie100:]*convcm2/Zch[2]**alpha,
             co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS3int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS3int[i][ie100:]*convcm2/Zch[3]**alpha,
             co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS3int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS3int[i][ie100:]*convcm2/Zch[4]**alpha,
             co_o,linewidth=1, label='_nolegend_')
# experiments
Ap, = plt.plot(A_p['E']/1000,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Up, = plt.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRp, = plt.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRe, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFp, = plt.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe09, = plt.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe17, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe19, = plt.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

plt.xlabel(r"Impact Energy/Z$^{2-\alpha}$ (MeV/amu)", fontsize=ilabelsize,labelpad=5)
plt.ylabel(r"$\sigma_e/Z^{\alpha}$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15)
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig("../zmol_alpha.eps",bbox_inches='tight')
plt.show()

# %%
# %matplotlib inline
from ipywidgets import interactive
import ipywidgets as widgets

import matplotlib.pyplot as plt
import numpy as np

def f(alpha):
    fig = plt.figure(figsize=(18,9))

    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')

    ax1 = plt.subplot(111)
    for i in head_adn[1:]:
        plt.plot(convMeV(PS1int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS1int[i][ie100:]*convcm2/Zch[0]**alpha,
                 co_p,linewidth=1)
        plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS1int[i][ie100:]*convcm2/Zch[1]**alpha,
                 co_he,linewidth=1)
        plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS1int[i][ie100:]*convcm2/Zch[2]**alpha,
                 co_be,linewidth=1)
        plt.plot(convMeV(CS1int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS1int[i][ie100:]*convcm2/Zch[3]**alpha,
                 co_c,linewidth=1)
        plt.plot(convMeV(OS1int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS1int[i][ie100:]*convcm2/Zch[4]**alpha,
                 co_o,linewidth=1)
    for i in head_CHn[1:]:
        plt.plot(convMeV(PS2int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS2int[i][ie100:]*convcm2/Zch[0]**alpha,
                 co_p,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(HeS2int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS2int[i][ie100:]*convcm2/Zch[1]**alpha,
                 co_he,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(BeS2int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS2int[i][ie100:]*convcm2/Zch[2]**alpha,
                 co_be,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(CS2int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS2int[i][ie100:]*convcm2/Zch[3]**alpha,
                 co_c,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(OS2int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS2int[i][ie100:]*convcm2/Zch[4]**alpha,
                 co_o,linewidth=1, label='_nolegend_')
    for i in head_PYR[1:]:
        plt.plot(convMeV(PS3int['ENERGY'][ie100:])/Zch[0]**(2-alpha),PS3int[i][ie100:]*convcm2/Zch[0]**alpha,
                 co_p,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/Zch[1]**(2-alpha),HeS3int[i][ie100:]*convcm2/Zch[1]**alpha,
                 co_he,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/Zch[2]**(2-alpha),BeS3int[i][ie100:]*convcm2/Zch[2]**alpha,
                 co_be,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(CS3int['ENERGY'][ie100:])/Zch[3]**(2-alpha),CS3int[i][ie100:]*convcm2/Zch[3]**alpha,
                 co_c,linewidth=1, label='_nolegend_')
        plt.plot(convMeV(OS3int['ENERGY'][ie100:])/Zch[4]**(2-alpha),OS3int[i][ie100:]*convcm2/Zch[4]**alpha,
                 co_o,linewidth=1, label='_nolegend_')
    # experiments
    Ap, = plt.plot(A_p['E']/1000,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    Up, = plt.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    PYRp, = plt.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    PYRe, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    THFp, = plt.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    THFe09, = plt.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    THFe17, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
    THFe19, = plt.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

    plt.xlabel(r"Impact Energy/Z$^{2-\alpha}$ (MeV/amu)", fontsize=ilabelsize,labelpad=5)
    plt.ylabel(r"$\sigma_e/Z^{\alpha}$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15)
    ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
    ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
    # plt.xlim(xmin,xmax)
    # plt.ylim(ymin,ymax)
    plt.yscale('log')
    plt.xscale('log')
    ax1.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
    ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

    fig.subplots_adjust(hspace=0.05, wspace=0.05)
    plt.show()



interactive_plot = interactive(f, alpha=widgets.FloatSlider(
    value=1.0,
    min=0.8,
    max=1.30,
    step=0.01,))
output = interactive_plot.children[-1]
output.layout.height = '540px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=1.3, min=0.8, step=0.01), Output(layout=…

# %%
ymin=0.02
ymax=20
xmin=convMeV(1.5)
xmax=convMeV(20.)
xtext=5
ytext=10
icharge=65/1000

fig = plt.figure(figsize=(18,9))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = plt.subplot(111)
# plt.text(0.13, 0.05, 'Present work',fontsize=imolsize)

for i in head_adn[1:]:
    plt.plot(convMeV(PS1int['ENERGY'][ie100:]),PS1int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS1int['ENERGY'][ie100:])/2**(2/3),HeS1int[i][ie100:]*convcm2/2**(4/3),co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS1int['ENERGY'][ie100:])/4**(2/3)**(2/3),BeS1int[i][ie100:]*convcm2/4**(4/3),co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS1int['ENERGY'][ie100:])/6**(2/3),CS1int[i][ie100:]*convcm2/6**(4/3),co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS1int['ENERGY'][ie100:])/8**(2/3),OS1int[i][ie100:]*convcm2/8**(4/3),co_o,linewidth=1, label='_nolegend_')
for i in head_CHn[1:]:
    plt.plot(convMeV(PS2int['ENERGY'][ie100:]),PS2int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS2int['ENERGY'][ie100:])/2**(2/3),HeS2int[i][ie100:]*convcm2/2**(4/3),co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS2int['ENERGY'][ie100:])/4**(2/3),BeS2int[i][ie100:]*convcm2/4**(4/3),co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS2int['ENERGY'][ie100:])/6**(2/3),CS2int[i][ie100:]*convcm2/6**(4/3),co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS2int['ENERGY'][ie100:])/8**(2/3),OS2int[i][ie100:]*convcm2/8**(4/3),co_o,linewidth=1, label='_nolegend_')
for i in head_PYR[1:]:
    plt.plot(convMeV(PS3int['ENERGY'][ie100:]),PS3int[i][ie100:]*convcm2,co_p,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(HeS3int['ENERGY'][ie100:])/2**(2/3),HeS3int[i][ie100:]*convcm2/2**(4/3),co_he,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(BeS3int['ENERGY'][ie100:])/4**(2/3),BeS3int[i][ie100:]*convcm2/4**(4/3),co_be,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(CS3int['ENERGY'][ie100:])/6**(2/3),CS3int[i][ie100:]*convcm2/6**(4/3),co_c,linewidth=1, label='_nolegend_')
    plt.plot(convMeV(OS3int['ENERGY'][ie100:])/8**(2/3),OS3int[i][ie100:]*convcm2/8**(4/3),co_o,linewidth=1, label='_nolegend_')
# experiments
Ap, = plt.plot(A_p['E']/1000,A_p['CS']/45,color=co_p,marker='o',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
Up, = plt.plot(U_p['E']/1000,U_p['CS']/36,color=co_p,marker='^',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRp, = plt.plot(PYR_p['E'][2:]/1000,PYR_p['au'][2:]/28*convcm2,color=co_p,marker='v',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
PYRe, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+PY']/28,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFp, = plt.plot(THF_p['Ep']/1000,THF_p['au']/28*convcm2,color=co_p,marker='D',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe09, = plt.plot(THF_e09['Ep(kev)']/1000,THF_e09['CS']/28,color='dimgray',marker='*',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe17, = plt.plot(bug17['Ep(keV)']/1000,bug17['e+THF']/28,color='dimgray',marker='<',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')
THFe19, = plt.plot(convMeV(THF_e19['v(au)'][0:iTHFe19]),THF_e19['au'][0:iTHFe19]/28*convcm2,color='dimgray',marker='>',markersize=14,markeredgewidth=1.5,markerfacecolor='none',linestyle=' ',label='_nolegend_')

plt.xlabel(r"Impact Energy/$Z^{2/3}$ (MeV/amu)", fontsize=ilabelsize,labelpad=5)
plt.ylabel(r"$\sigma_e/Z^{4/3}$ ($10^{-16}$ cm$^2$)", fontsize=ilabelsize,labelpad=15)
ax1.tick_params(direction='in',which='major',labelsize=itickssize,length=8,bottom=True, top=True, left=True, right=True);
ax1.tick_params(direction='in',which='minor',length=6,bottom=True, top=True, left=True, right=True);
# plt.xlim(xmin,xmax)
# plt.ylim(ymin,ymax)
plt.yscale('log')
plt.xscale('log')
ax1.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))
ax1.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,g}'))

fig.subplots_adjust(hspace=0.05, wspace=0.05)

plt.savefig("../z13mol85.eps",bbox_inches='tight')
plt.show()

# %%
2/3
# Out:
# 0.6666666666666666

# %%
4/3
# Out:
# 1.3333333333333333
